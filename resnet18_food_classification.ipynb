# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/food11/validation/8_248.jpg
# /kaggle/input/food11/validation/5_365.jpg
# /kaggle/input/food11/validation/8_210.jpg
# /kaggle/input/food11/validation/5_0.jpg
# /kaggle/input/food11/validation/9_104.jpg
# /kaggle/input/food11/validation/0_307.jpg
# /kaggle/input/food11/validation/3_200.jpg
# /kaggle/input/food11/validation/5_59.jpg
# /kaggle/input/food11/validation/2_245.jpg
# /kaggle/input/food11/validation/9_276.jpg
# /kaggle/input/food11/validation/8_209.jpg
# /kaggle/input/food11/validation/2_178.jpg
# /kaggle/input/food11/validation/9_85.jpg
# /kaggle/input/food11/validation/9_161.jpg
# /kaggle/input/food11/validation/4_316.jpg
# /kaggle/input/food11/validation/0_249.jpg
# /kaggle/input/food11/validation/4_122.jpg
# /kaggle/input/food11/validation/9_403.jpg
# /kaggle/input/food11/validation/0_217.jpg
# /kaggle/input/food11/validation/3_193.jpg
# /kaggle/input/food11/validation/2_374.jpg
# /kaggle/input/food11/validation/5_376.jpg
# /kaggle/input/food11/validation/0_354.jpg
# /kaggle/input/food11/validation/0_287.jpg
# /kaggle/input/food11/validation/10_150.jpg
# /kaggle/input/food11/validation/10_98.jpg
# /kaggle/input/food11/validation/9_458.jpg
# /kaggle/input/food11/validation/10_195.jpg
# /kaggle/input/food11/validation/0_31.jpg
# /kaggle/input/food11/validation/6_45.jpg
# /kaggle/input/food11/validation/2_268.jpg
# /kaggle/input/food11/validation/0_16.jpg
# /kaggle/input/food11/validation/3_7.jpg
# /kaggle/input/food11/validation/4_77.jpg
# /kaggle/input/food11/validation/10_161.jpg
# /kaggle/input/food11/validation/0_168.jpg
# /kaggle/input/food11/validation/3_95.jpg
# /kaggle/input/food11/validation/9_39.jpg
# /kaggle/input/food11/validation/9_64.jpg
# /kaggle/input/food11/validation/8_59.jpg
# /kaggle/input/food11/validation/4_292.jpg
# /kaggle/input/food11/validation/2_57.jpg
# /kaggle/input/food11/validation/10_88.jpg
# /kaggle/input/food11/validation/0_228.jpg
# /kaggle/input/food11/validation/5_120.jpg
# /kaggle/input/food11/validation/10_196.jpg
# /kaggle/input/food11/validation/2_356.jpg
# /kaggle/input/food11/validation/8_139.jpg
# /kaggle/input/food11/validation/3_204.jpg
# /kaggle/input/food11/validation/5_433.jpg
# /kaggle/input/food11/validation/0_24.jpg
# /kaggle/input/food11/validation/8_207.jpg
# /kaggle/input/food11/validation/2_255.jpg
# /kaggle/input/food11/validation/2_434.jpg
# /kaggle/input/food11/validation/5_223.jpg
# /kaggle/input/food11/validation/9_254.jpg
# /kaggle/input/food11/validation/4_85.jpg
# /kaggle/input/food11/validation/1_8.jpg
# /kaggle/input/food11/validation/4_250.jpg
# /kaggle/input/food11/validation/3_249.jpg
# /kaggle/input/food11/validation/3_247.jpg
# /kaggle/input/food11/validation/9_494.jpg
# /kaggle/input/food11/validation/4_240.jpg
# /kaggle/input/food11/validation/0_49.jpg
# /kaggle/input/food11/validation/1_23.jpg
# /kaggle/input/food11/validation/8_157.jpg
# /kaggle/input/food11/validation/6_6.jpg
# /kaggle/input/food11/validation/10_89.jpg
# /kaggle/input/food11/validation/9_34.jpg
# /kaggle/input/food11/validation/3_77.jpg
# /kaggle/input/food11/validation/2_264.jpg
# /kaggle/input/food11/validation/4_212.jpg
# /kaggle/input/food11/validation/3_42.jpg
# /kaggle/input/food11/validation/3_179.jpg
# /kaggle/input/food11/validation/3_43.jpg
# /kaggle/input/food11/validation/2_224.jpg
# /kaggle/input/food11/validation/3_269.jpg
# /kaggle/input/food11/validation/5_188.jpg
# /kaggle/input/food11/validation/3_292.jpg
# /kaggle/input/food11/validation/2_74.jpg
# /kaggle/input/food11/validation/2_486.jpg
# /kaggle/input/food11/validation/3_112.jpg
# /kaggle/input/food11/validation/0_293.jpg
# /kaggle/input/food11/validation/0_45.jpg
# /kaggle/input/food11/validation/4_9.jpg
# /kaggle/input/food11/validation/4_114.jpg
# /kaggle/input/food11/validation/2_354.jpg
# /kaggle/input/food11/validation/0_135.jpg
# /kaggle/input/food11/validation/3_149.jpg
# /kaggle/input/food11/validation/5_172.jpg
# /kaggle/input/food11/validation/5_267.jpg
# /kaggle/input/food11/validation/9_250.jpg
# /kaggle/input/food11/validation/9_48.jpg
# /kaggle/input/food11/validation/3_175.jpg
# /kaggle/input/food11/validation/3_189.jpg
# /kaggle/input/food11/validation/5_240.jpg
# /kaggle/input/food11/validation/2_398.jpg
# /kaggle/input/food11/validation/5_199.jpg
# /kaggle/input/food11/validation/4_236.jpg
# /kaggle/input/food11/validation/0_96.jpg
# /kaggle/input/food11/validation/9_194.jpg
# /kaggle/input/food11/validation/0_209.jpg
# /kaggle/input/food11/validation/3_128.jpg
# /kaggle/input/food11/validation/10_33.jpg
# /kaggle/input/food11/validation/2_419.jpg
# /kaggle/input/food11/validation/4_157.jpg
# /kaggle/input/food11/validation/8_190.jpg
# /kaggle/input/food11/validation/5_351.jpg
# /kaggle/input/food11/validation/2_169.jpg
# /kaggle/input/food11/validation/5_280.jpg
# /kaggle/input/food11/validation/2_483.jpg
# /kaggle/input/food11/validation/9_93.jpg
# /kaggle/input/food11/validation/0_308.jpg
# /kaggle/input/food11/validation/6_4.jpg
# /kaggle/input/food11/validation/2_478.jpg
# /kaggle/input/food11/validation/3_127.jpg
# /kaggle/input/food11/validation/6_126.jpg
# /kaggle/input/food11/validation/0_331.jpg
# /kaggle/input/food11/validation/5_34.jpg
# /kaggle/input/food11/validation/5_129.jpg
# /kaggle/input/food11/validation/2_144.jpg
# /kaggle/input/food11/validation/2_35.jpg
# /kaggle/input/food11/validation/2_237.jpg
# /kaggle/input/food11/validation/9_368.jpg
# /kaggle/input/food11/validation/8_64.jpg
# /kaggle/input/food11/validation/2_156.jpg
# /kaggle/input/food11/validation/5_405.jpg
# /kaggle/input/food11/validation/5_394.jpg
# /kaggle/input/food11/validation/4_299.jpg
# /kaggle/input/food11/validation/9_43.jpg
# /kaggle/input/food11/validation/4_166.jpg
# /kaggle/input/food11/validation/2_246.jpg
# /kaggle/input/food11/validation/6_59.jpg
# /kaggle/input/food11/validation/2_364.jpg
# /kaggle/input/food11/validation/3_195.jpg
# /kaggle/input/food11/validation/7_10.jpg
# /kaggle/input/food11/validation/4_293.jpg
# /kaggle/input/food11/validation/0_300.jpg
# /kaggle/input/food11/validation/10_49.jpg
# /kaggle/input/food11/validation/3_2.jpg
# /kaggle/input/food11/validation/4_87.jpg
# /kaggle/input/food11/validation/9_291.jpg
# /kaggle/input/food11/validation/3_217.jpg
# /kaggle/input/food11/validation/0_231.jpg
# /kaggle/input/food11/validation/3_246.jpg
# /kaggle/input/food11/validation/2_273.jpg
# /kaggle/input/food11/validation/0_66.jpg
# /kaggle/input/food11/validation/2_75.jpg
# /kaggle/input/food11/validation/4_180.jpg
# /kaggle/input/food11/validation/2_138.jpg
# /kaggle/input/food11/validation/9_137.jpg
# /kaggle/input/food11/validation/2_219.jpg
# /kaggle/input/food11/validation/5_166.jpg
# /kaggle/input/food11/validation/2_439.jpg
# /kaggle/input/food11/validation/2_126.jpg
# /kaggle/input/food11/validation/0_325.jpg
# /kaggle/input/food11/validation/9_401.jpg
# /kaggle/input/food11/validation/2_231.jpg
# /kaggle/input/food11/validation/1_3.jpg
# /kaggle/input/food11/validation/5_318.jpg
# /kaggle/input/food11/validation/4_84.jpg
# /kaggle/input/food11/validation/2_123.jpg
# /kaggle/input/food11/validation/0_344.jpg
# /kaggle/input/food11/validation/4_323.jpg
# /kaggle/input/food11/validation/10_178.jpg
# /kaggle/input/food11/validation/4_33.jpg
# /kaggle/input/food11/validation/4_254.jpg
# /kaggle/input/food11/validation/10_206.jpg
# /kaggle/input/food11/validation/2_322.jpg
# /kaggle/input/food11/validation/3_323.jpg
# /kaggle/input/food11/validation/2_266.jpg
# /kaggle/input/food11/validation/2_459.jpg
# /kaggle/input/food11/validation/0_52.jpg
# /kaggle/input/food11/validation/3_107.jpg
# /kaggle/input/food11/validation/0_84.jpg
# /kaggle/input/food11/validation/1_100.jpg
# /kaggle/input/food11/validation/2_367.jpg
# /kaggle/input/food11/validation/0_296.jpg
# /kaggle/input/food11/validation/8_169.jpg
# /kaggle/input/food11/validation/1_85.jpg
# /kaggle/input/food11/validation/4_19.jpg
# /kaggle/input/food11/validation/10_205.jpg
# /kaggle/input/food11/validation/4_97.jpg
# /kaggle/input/food11/validation/9_173.jpg
# /kaggle/input/food11/validation/0_59.jpg
# /kaggle/input/food11/validation/9_245.jpg
# /kaggle/input/food11/validation/5_175.jpg
# /kaggle/input/food11/validation/10_154.jpg
# /kaggle/input/food11/validation/4_230.jpg
# /kaggle/input/food11/validation/0_212.jpg
# /kaggle/input/food11/validation/4_14.jpg
# /kaggle/input/food11/validation/2_253.jpg
# /kaggle/input/food11/validation/9_209.jpg
# /kaggle/input/food11/validation/0_86.jpg
# /kaggle/input/food11/validation/6_96.jpg
# /kaggle/input/food11/validation/3_182.jpg
# /kaggle/input/food11/validation/3_171.jpg
# /kaggle/input/food11/validation/4_278.jpg
# /kaggle/input/food11/validation/0_190.jpg
# /kaggle/input/food11/validation/5_335.jpg
# /kaggle/input/food11/validation/0_210.jpg
# /kaggle/input/food11/validation/10_191.jpg
# /kaggle/input/food11/validation/2_431.jpg
# /kaggle/input/food11/validation/2_82.jpg
# /kaggle/input/food11/validation/9_1.jpg
# /kaggle/input/food11/validation/3_136.jpg
# /kaggle/input/food11/validation/9_133.jpg
# /kaggle/input/food11/validation/5_428.jpg
# /kaggle/input/food11/validation/0_30.jpg
# /kaggle/input/food11/validation/8_345.jpg
# /kaggle/input/food11/validation/9_407.jpg
# /kaggle/input/food11/validation/8_320.jpg
# /kaggle/input/food11/validation/1_141.jpg
# /kaggle/input/food11/validation/8_266.jpg
# /kaggle/input/food11/validation/9_309.jpg
# /kaggle/input/food11/validation/0_39.jpg
# /kaggle/input/food11/validation/2_65.jpg
# /kaggle/input/food11/validation/0_179.jpg
# /kaggle/input/food11/validation/4_39.jpg
# /kaggle/input/food11/validation/10_221.jpg
# /kaggle/input/food11/validation/0_109.jpg
# /kaggle/input/food11/validation/3_224.jpg
# /kaggle/input/food11/validation/5_419.jpg
# /kaggle/input/food11/validation/5_77.jpg
# /kaggle/input/food11/validation/1_73.jpg
# /kaggle/input/food11/validation/1_139.jpg
# /kaggle/input/food11/validation/5_3.jpg
# /kaggle/input/food11/validation/8_107.jpg
# /kaggle/input/food11/validation/2_106.jpg
# /kaggle/input/food11/validation/0_20.jpg
# /kaggle/input/food11/validation/4_113.jpg
# /kaggle/input/food11/validation/5_206.jpg
# /kaggle/input/food11/validation/9_251.jpg
# /kaggle/input/food11/validation/0_216.jpg
# /kaggle/input/food11/validation/6_65.jpg
# /kaggle/input/food11/validation/0_62.jpg
# /kaggle/input/food11/validation/4_246.jpg
# /kaggle/input/food11/validation/1_87.jpg
# /kaggle/input/food11/validation/4_117.jpg
# /kaggle/input/food11/validation/8_21.jpg
# /kaggle/input/food11/validation/8_22.jpg
# /kaggle/input/food11/validation/6_62.jpg
# /kaggle/input/food11/validation/8_94.jpg
# /kaggle/input/food11/validation/3_22.jpg
# /kaggle/input/food11/validation/0_332.jpg
# /kaggle/input/food11/validation/0_315.jpg
# /kaggle/input/food11/validation/9_15.jpg
# /kaggle/input/food11/validation/2_465.jpg
# /kaggle/input/food11/validation/2_470.jpg
# /kaggle/input/food11/validation/9_406.jpg
# /kaggle/input/food11/validation/4_182.jpg
# /kaggle/input/food11/validation/8_103.jpg
# /kaggle/input/food11/validation/5_291.jpg
# /kaggle/input/food11/validation/8_301.jpg
# /kaggle/input/food11/validation/3_173.jpg
# /kaggle/input/food11/validation/0_99.jpg
# /kaggle/input/food11/validation/2_180.jpg
# /kaggle/input/food11/validation/2_238.jpg
# /kaggle/input/food11/validation/2_97.jpg
# /kaggle/input/food11/validation/8_272.jpg
# /kaggle/input/food11/validation/3_141.jpg
# /kaggle/input/food11/validation/10_15.jpg
# /kaggle/input/food11/validation/5_310.jpg
# /kaggle/input/food11/validation/10_147.jpg
# /kaggle/input/food11/validation/1_123.jpg
# /kaggle/input/food11/validation/9_125.jpg
# /kaggle/input/food11/validation/8_206.jpg
# /kaggle/input/food11/validation/8_327.jpg
# /kaggle/input/food11/validation/9_128.jpg
# /kaggle/input/food11/validation/4_111.jpg
# /kaggle/input/food11/validation/2_91.jpg
# /kaggle/input/food11/validation/0_58.jpg
# /kaggle/input/food11/validation/0_167.jpg
# /kaggle/input/food11/validation/3_33.jpg
# /kaggle/input/food11/validation/2_406.jpg
# /kaggle/input/food11/validation/10_18.jpg
# /kaggle/input/food11/validation/5_416.jpg
# /kaggle/input/food11/validation/10_30.jpg
# /kaggle/input/food11/validation/1_19.jpg
# /kaggle/input/food11/validation/5_122.jpg
# /kaggle/input/food11/validation/9_482.jpg
# /kaggle/input/food11/validation/5_84.jpg
# /kaggle/input/food11/validation/4_206.jpg
# /kaggle/input/food11/validation/0_353.jpg
# /kaggle/input/food11/validation/1_97.jpg
# /kaggle/input/food11/validation/9_301.jpg
# /kaggle/input/food11/validation/4_0.jpg
# /kaggle/input/food11/validation/5_225.jpg
# /kaggle/input/food11/validation/2_432.jpg
# /kaggle/input/food11/validation/5_97.jpg
# /kaggle/input/food11/validation/5_387.jpg
# /kaggle/input/food11/validation/0_341.jpg
# /kaggle/input/food11/validation/0_330.jpg
# /kaggle/input/food11/validation/6_89.jpg
# /kaggle/input/food11/validation/2_300.jpg
# /kaggle/input/food11/validation/8_189.jpg
# /kaggle/input/food11/validation/2_400.jpg
# /kaggle/input/food11/validation/7_8.jpg
# /kaggle/input/food11/validation/5_224.jpg
# /kaggle/input/food11/validation/3_55.jpg
# /kaggle/input/food11/validation/3_261.jpg
# /kaggle/input/food11/validation/2_380.jpg
# /kaggle/input/food11/validation/7_67.jpg
# /kaggle/input/food11/validation/5_210.jpg
# /kaggle/input/food11/validation/9_353.jpg
# /kaggle/input/food11/validation/3_58.jpg
# /kaggle/input/food11/validation/8_75.jpg
# /kaggle/input/food11/validation/2_443.jpg
# /kaggle/input/food11/validation/8_174.jpg
# /kaggle/input/food11/validation/9_342.jpg
# /kaggle/input/food11/validation/2_410.jpg
# /kaggle/input/food11/validation/7_65.jpg
# /kaggle/input/food11/validation/2_394.jpg
# /kaggle/input/food11/validation/1_52.jpg
# /kaggle/input/food11/validation/1_77.jpg
# /kaggle/input/food11/validation/7_9.jpg
# /kaggle/input/food11/validation/0_194.jpg
# /kaggle/input/food11/validation/5_352.jpg
# /kaggle/input/food11/validation/1_118.jpg
# /kaggle/input/food11/validation/6_129.jpg
# /kaggle/input/food11/validation/2_30.jpg
# /kaggle/input/food11/validation/8_150.jpg
# /kaggle/input/food11/validation/2_148.jpg
# /kaggle/input/food11/validation/4_198.jpg
# /kaggle/input/food11/validation/10_230.jpg
# /kaggle/input/food11/validation/4_171.jpg
# /kaggle/input/food11/validation/1_137.jpg
# /kaggle/input/food11/validation/5_98.jpg
# /kaggle/input/food11/validation/9_157.jpg
# /kaggle/input/food11/validation/9_320.jpg
# /kaggle/input/food11/validation/0_283.jpg
# /kaggle/input/food11/validation/5_298.jpg
# /kaggle/input/food11/validation/10_141.jpg
# /kaggle/input/food11/validation/7_93.jpg
# /kaggle/input/food11/validation/8_65.jpg
# /kaggle/input/food11/validation/5_363.jpg
# /kaggle/input/food11/validation/5_250.jpg
# /kaggle/input/food11/validation/2_243.jpg
# /kaggle/input/food11/validation/3_181.jpg
# /kaggle/input/food11/validation/4_130.jpg
# /kaggle/input/food11/validation/2_263.jpg
# /kaggle/input/food11/validation/1_32.jpg
# /kaggle/input/food11/validation/4_74.jpg
# /kaggle/input/food11/validation/9_58.jpg
# /kaggle/input/food11/validation/5_76.jpg
# /kaggle/input/food11/validation/2_197.jpg
# /kaggle/input/food11/validation/5_89.jpg
# /kaggle/input/food11/validation/3_78.jpg
# /kaggle/input/food11/validation/1_82.jpg
# /kaggle/input/food11/validation/2_89.jpg
# /kaggle/input/food11/validation/8_23.jpg
# /kaggle/input/food11/validation/2_489.jpg
# /kaggle/input/food11/validation/10_225.jpg
# /kaggle/input/food11/validation/9_416.jpg
# /kaggle/input/food11/validation/2_377.jpg
# /kaggle/input/food11/validation/1_125.jpg
# /kaggle/input/food11/validation/9_274.jpg
# /kaggle/input/food11/validation/9_5.jpg
# /kaggle/input/food11/validation/6_140.jpg
# /kaggle/input/food11/validation/9_22.jpg
# /kaggle/input/food11/validation/3_251.jpg
# /kaggle/input/food11/validation/8_148.jpg
# /kaggle/input/food11/validation/2_207.jpg
# /kaggle/input/food11/validation/4_220.jpg
# /kaggle/input/food11/validation/8_308.jpg
# /kaggle/input/food11/validation/3_52.jpg
# /kaggle/input/food11/validation/0_286.jpg
# /kaggle/input/food11/validation/9_88.jpg
# /kaggle/input/food11/validation/2_3.jpg
# /kaggle/input/food11/validation/5_64.jpg
# /kaggle/input/food11/validation/1_25.jpg
# /kaggle/input/food11/validation/3_159.jpg
# /kaggle/input/food11/validation/9_159.jpg
# /kaggle/input/food11/validation/10_78.jpg
# /kaggle/input/food11/validation/8_136.jpg
# /kaggle/input/food11/validation/0_275.jpg
# /kaggle/input/food11/validation/4_174.jpg
# /kaggle/input/food11/validation/3_178.jpg
# /kaggle/input/food11/validation/10_55.jpg
# /kaggle/input/food11/validation/9_210.jpg
# /kaggle/input/food11/validation/4_194.jpg
# /kaggle/input/food11/validation/4_30.jpg
# /kaggle/input/food11/validation/2_426.jpg
# /kaggle/input/food11/validation/8_129.jpg
# /kaggle/input/food11/validation/4_108.jpg
# /kaggle/input/food11/validation/0_111.jpg
# /kaggle/input/food11/validation/0_175.jpg
# /kaggle/input/food11/validation/3_123.jpg
# /kaggle/input/food11/validation/8_36.jpg
# /kaggle/input/food11/validation/5_40.jpg
# /kaggle/input/food11/validation/5_92.jpg
# /kaggle/input/food11/validation/9_399.jpg
# /kaggle/input/food11/validation/9_381.jpg
# /kaggle/input/food11/validation/6_125.jpg
# /kaggle/input/food11/validation/3_272.jpg
# /kaggle/input/food11/validation/0_120.jpg
# /kaggle/input/food11/validation/5_446.jpg
# /kaggle/input/food11/validation/6_124.jpg
# /kaggle/input/food11/validation/9_271.jpg
# /kaggle/input/food11/validation/3_56.jpg
# /kaggle/input/food11/validation/0_211.jpg
# /kaggle/input/food11/validation/3_172.jpg
# /kaggle/input/food11/validation/10_175.jpg
# /kaggle/input/food11/validation/3_13.jpg
# /kaggle/input/food11/validation/4_78.jpg
# /kaggle/input/food11/validation/7_68.jpg
# /kaggle/input/food11/validation/9_408.jpg
# /kaggle/input/food11/validation/4_53.jpg
# /kaggle/input/food11/validation/10_109.jpg
# /kaggle/input/food11/validation/0_208.jpg
# /kaggle/input/food11/validation/2_292.jpg
# /kaggle/input/food11/validation/0_87.jpg
# /kaggle/input/food11/validation/5_41.jpg
# /kaggle/input/food11/validation/10_73.jpg
# /kaggle/input/food11/validation/0_3.jpg
# /kaggle/input/food11/validation/6_54.jpg
# /kaggle/input/food11/validation/9_313.jpg
# /kaggle/input/food11/validation/0_356.jpg
# /kaggle/input/food11/validation/5_300.jpg
# /kaggle/input/food11/validation/10_152.jpg
# /kaggle/input/food11/validation/4_243.jpg
# /kaggle/input/food11/validation/4_127.jpg
# /kaggle/input/food11/validation/5_442.jpg
# /kaggle/input/food11/validation/9_138.jpg
# /kaggle/input/food11/validation/1_26.jpg
# /kaggle/input/food11/validation/9_60.jpg
# /kaggle/input/food11/validation/10_157.jpg
# /kaggle/input/food11/validation/5_432.jpg
# /kaggle/input/food11/validation/9_347.jpg
# /kaggle/input/food11/validation/8_111.jpg
# /kaggle/input/food11/validation/3_177.jpg
# /kaggle/input/food11/validation/8_101.jpg
# /kaggle/input/food11/validation/2_4.jpg
# /kaggle/input/food11/validation/8_246.jpg
# /kaggle/input/food11/validation/5_275.jpg
# /kaggle/input/food11/validation/10_160.jpg
# /kaggle/input/food11/validation/5_195.jpg
# /kaggle/input/food11/validation/5_246.jpg
# /kaggle/input/food11/validation/8_134.jpg
# /kaggle/input/food11/validation/2_208.jpg
# /kaggle/input/food11/validation/10_143.jpg
# /kaggle/input/food11/validation/4_131.jpg
# /kaggle/input/food11/validation/8_119.jpg
# /kaggle/input/food11/validation/5_99.jpg
# /kaggle/input/food11/validation/2_306.jpg
# /kaggle/input/food11/validation/3_214.jpg
# /kaggle/input/food11/validation/9_435.jpg
# /kaggle/input/food11/validation/3_207.jpg
# /kaggle/input/food11/validation/3_188.jpg
# /kaggle/input/food11/validation/3_12.jpg
# /kaggle/input/food11/validation/5_29.jpg
# /kaggle/input/food11/validation/3_92.jpg
# /kaggle/input/food11/validation/9_111.jpg
# /kaggle/input/food11/validation/4_319.jpg
# /kaggle/input/food11/validation/9_323.jpg
# /kaggle/input/food11/validation/3_174.jpg
# /kaggle/input/food11/validation/4_95.jpg
# /kaggle/input/food11/validation/4_307.jpg
# /kaggle/input/food11/validation/4_315.jpg
# /kaggle/input/food11/validation/2_22.jpg
# /kaggle/input/food11/validation/3_271.jpg
# /kaggle/input/food11/validation/10_8.jpg
# /kaggle/input/food11/validation/9_170.jpg
# /kaggle/input/food11/validation/2_95.jpg
# /kaggle/input/food11/validation/10_103.jpg
# /kaggle/input/food11/validation/6_18.jpg
# /kaggle/input/food11/validation/8_275.jpg
# /kaggle/input/food11/validation/9_116.jpg
# /kaggle/input/food11/validation/0_82.jpg
# /kaggle/input/food11/validation/6_58.jpg
# /kaggle/input/food11/validation/3_169.jpg
# /kaggle/input/food11/validation/0_5.jpg
# /kaggle/input/food11/validation/7_27.jpg
# /kaggle/input/food11/validation/5_151.jpg
# /kaggle/input/food11/validation/3_105.jpg
# /kaggle/input/food11/validation/5_54.jpg
# /kaggle/input/food11/validation/4_262.jpg
# /kaggle/input/food11/validation/5_105.jpg
# /kaggle/input/food11/validation/5_137.jpg
# /kaggle/input/food11/validation/0_191.jpg
# /kaggle/input/food11/validation/4_218.jpg
# /kaggle/input/food11/validation/8_48.jpg
# /kaggle/input/food11/validation/9_457.jpg
# /kaggle/input/food11/validation/3_192.jpg
# /kaggle/input/food11/validation/10_105.jpg
# /kaggle/input/food11/validation/8_118.jpg
# /kaggle/input/food11/validation/6_91.jpg
# /kaggle/input/food11/validation/5_288.jpg
# /kaggle/input/food11/validation/6_47.jpg
# /kaggle/input/food11/validation/6_48.jpg
# /kaggle/input/food11/validation/5_187.jpg
# /kaggle/input/food11/validation/4_49.jpg
# /kaggle/input/food11/validation/0_326.jpg
# /kaggle/input/food11/validation/10_50.jpg
# /kaggle/input/food11/validation/6_101.jpg
# /kaggle/input/food11/validation/2_157.jpg
# /kaggle/input/food11/validation/5_330.jpg
# /kaggle/input/food11/validation/5_184.jpg
# /kaggle/input/food11/validation/5_281.jpg
# /kaggle/input/food11/validation/2_32.jpg
# /kaggle/input/food11/validation/9_166.jpg
# /kaggle/input/food11/validation/5_106.jpg
# /kaggle/input/food11/validation/4_47.jpg
# /kaggle/input/food11/validation/9_292.jpg
# /kaggle/input/food11/validation/1_66.jpg
# /kaggle/input/food11/validation/2_402.jpg
# /kaggle/input/food11/validation/5_357.jpg
# /kaggle/input/food11/validation/10_183.jpg
# /kaggle/input/food11/validation/0_317.jpg
# /kaggle/input/food11/validation/2_330.jpg
# /kaggle/input/food11/validation/4_54.jpg
# /kaggle/input/food11/validation/9_66.jpg
# /kaggle/input/food11/validation/4_325.jpg
# /kaggle/input/food11/validation/9_108.jpg
# /kaggle/input/food11/validation/5_134.jpg
# /kaggle/input/food11/validation/8_306.jpg
# /kaggle/input/food11/validation/3_228.jpg
# /kaggle/input/food11/validation/2_298.jpg
# /kaggle/input/food11/validation/9_152.jpg
# /kaggle/input/food11/validation/0_2.jpg
# /kaggle/input/food11/validation/3_223.jpg
# /kaggle/input/food11/validation/0_177.jpg
# /kaggle/input/food11/validation/0_74.jpg
# /kaggle/input/food11/validation/5_9.jpg
# /kaggle/input/food11/validation/0_128.jpg
# /kaggle/input/food11/validation/9_217.jpg
# /kaggle/input/food11/validation/2_136.jpg
# /kaggle/input/food11/validation/2_389.jpg
# /kaggle/input/food11/validation/5_277.jpg
# /kaggle/input/food11/validation/2_373.jpg
# /kaggle/input/food11/validation/2_81.jpg
# /kaggle/input/food11/validation/9_362.jpg
# /kaggle/input/food11/validation/9_266.jpg
# /kaggle/input/food11/validation/8_72.jpg
# /kaggle/input/food11/validation/4_86.jpg
# /kaggle/input/food11/validation/2_103.jpg
# /kaggle/input/food11/validation/5_294.jpg
# /kaggle/input/food11/validation/8_267.jpg
# /kaggle/input/food11/validation/4_101.jpg
# /kaggle/input/food11/validation/3_80.jpg
# /kaggle/input/food11/validation/4_227.jpg
# /kaggle/input/food11/validation/10_68.jpg
# /kaggle/input/food11/validation/8_71.jpg
# /kaggle/input/food11/validation/3_139.jpg
# /kaggle/input/food11/validation/5_233.jpg
# /kaggle/input/food11/validation/5_174.jpg
# /kaggle/input/food11/validation/6_35.jpg
# /kaggle/input/food11/validation/4_301.jpg
# /kaggle/input/food11/validation/8_274.jpg
# /kaggle/input/food11/validation/5_385.jpg
# /kaggle/input/food11/validation/2_141.jpg
# /kaggle/input/food11/validation/1_109.jpg
# /kaggle/input/food11/validation/1_7.jpg
# /kaggle/input/food11/validation/4_66.jpg
# /kaggle/input/food11/validation/9_92.jpg
# /kaggle/input/food11/validation/2_90.jpg
# /kaggle/input/food11/validation/10_223.jpg
# /kaggle/input/food11/validation/2_162.jpg
# /kaggle/input/food11/validation/5_251.jpg
# /kaggle/input/food11/validation/0_221.jpg
# /kaggle/input/food11/validation/8_6.jpg
# /kaggle/input/food11/validation/3_202.jpg
# /kaggle/input/food11/validation/8_282.jpg
# /kaggle/input/food11/validation/4_235.jpg
# /kaggle/input/food11/validation/5_153.jpg
# /kaggle/input/food11/validation/9_283.jpg
# /kaggle/input/food11/validation/0_165.jpg
# /kaggle/input/food11/validation/4_34.jpg
# /kaggle/input/food11/validation/0_199.jpg
# /kaggle/input/food11/validation/3_70.jpg
# /kaggle/input/food11/validation/8_99.jpg
# /kaggle/input/food11/validation/6_77.jpg
# /kaggle/input/food11/validation/8_268.jpg
# /kaggle/input/food11/validation/2_198.jpg
# /kaggle/input/food11/validation/2_344.jpg
# /kaggle/input/food11/validation/8_122.jpg
# /kaggle/input/food11/validation/4_289.jpg
# /kaggle/input/food11/validation/1_31.jpg
# /kaggle/input/food11/validation/2_107.jpg
# /kaggle/input/food11/validation/5_241.jpg
# /kaggle/input/food11/validation/8_91.jpg
# /kaggle/input/food11/validation/8_97.jpg
# /kaggle/input/food11/validation/6_37.jpg
# /kaggle/input/food11/validation/2_121.jpg
# /kaggle/input/food11/validation/4_146.jpg
# /kaggle/input/food11/validation/9_195.jpg
# /kaggle/input/food11/validation/5_167.jpg
# /kaggle/input/food11/validation/0_305.jpg
# /kaggle/input/food11/validation/9_352.jpg
# /kaggle/input/food11/validation/4_287.jpg
# /kaggle/input/food11/validation/8_269.jpg
# /kaggle/input/food11/validation/5_342.jpg
# /kaggle/input/food11/validation/2_485.jpg
# /kaggle/input/food11/validation/1_132.jpg
# /kaggle/input/food11/validation/4_324.jpg
# /kaggle/input/food11/validation/2_109.jpg
# /kaggle/input/food11/validation/3_125.jpg
# /kaggle/input/food11/validation/5_219.jpg
# /kaggle/input/food11/validation/9_329.jpg
# /kaggle/input/food11/validation/5_15.jpg
# /kaggle/input/food11/validation/2_487.jpg
# /kaggle/input/food11/validation/2_312.jpg
# /kaggle/input/food11/validation/6_70.jpg
# /kaggle/input/food11/validation/6_102.jpg
# /kaggle/input/food11/validation/9_328.jpg
# /kaggle/input/food11/validation/9_65.jpg
# /kaggle/input/food11/validation/3_305.jpg
# /kaggle/input/food11/validation/1_107.jpg
# /kaggle/input/food11/validation/4_288.jpg
# /kaggle/input/food11/validation/2_340.jpg
# /kaggle/input/food11/validation/8_164.jpg
# /kaggle/input/food11/validation/9_37.jpg
# /kaggle/input/food11/validation/2_135.jpg
# /kaggle/input/food11/validation/9_474.jpg
# /kaggle/input/food11/validation/9_103.jpg
# /kaggle/input/food11/validation/7_59.jpg
# /kaggle/input/food11/validation/1_138.jpg
# /kaggle/input/food11/validation/0_33.jpg
# /kaggle/input/food11/validation/10_186.jpg
# /kaggle/input/food11/validation/6_63.jpg
# /kaggle/input/food11/validation/9_202.jpg
# /kaggle/input/food11/validation/3_264.jpg
# /kaggle/input/food11/validation/10_65.jpg
# /kaggle/input/food11/validation/10_75.jpg
# /kaggle/input/food11/validation/3_197.jpg
# /kaggle/input/food11/validation/9_324.jpg
# /kaggle/input/food11/validation/9_97.jpg
# /kaggle/input/food11/validation/5_325.jpg
# /kaggle/input/food11/validation/2_122.jpg
# /kaggle/input/food11/validation/8_225.jpg
# /kaggle/input/food11/validation/4_310.jpg
# /kaggle/input/food11/validation/5_237.jpg
# /kaggle/input/food11/validation/2_497.jpg
# /kaggle/input/food11/validation/9_333.jpg
# /kaggle/input/food11/validation/5_216.jpg
# /kaggle/input/food11/validation/5_375.jpg
# /kaggle/input/food11/validation/4_50.jpg
# /kaggle/input/food11/validation/3_191.jpg
# /kaggle/input/food11/validation/8_171.jpg
# /kaggle/input/food11/validation/2_201.jpg
# /kaggle/input/food11/validation/0_242.jpg
# /kaggle/input/food11/validation/8_135.jpg
# /kaggle/input/food11/validation/2_391.jpg
# /kaggle/input/food11/validation/8_203.jpg
# /kaggle/input/food11/validation/3_278.jpg
# /kaggle/input/food11/validation/3_284.jpg
# /kaggle/input/food11/validation/7_12.jpg
# /kaggle/input/food11/validation/0_156.jpg
# /kaggle/input/food11/validation/4_138.jpg
# /kaggle/input/food11/validation/10_28.jpg
# /kaggle/input/food11/validation/0_196.jpg
# /kaggle/input/food11/validation/0_104.jpg
# /kaggle/input/food11/validation/2_296.jpg
# /kaggle/input/food11/validation/2_108.jpg
# /kaggle/input/food11/validation/9_171.jpg
# /kaggle/input/food11/validation/5_395.jpg
# /kaggle/input/food11/validation/2_175.jpg
# /kaggle/input/food11/validation/5_398.jpg
# /kaggle/input/food11/validation/9_167.jpg
# /kaggle/input/food11/validation/6_136.jpg
# /kaggle/input/food11/validation/5_235.jpg
# /kaggle/input/food11/validation/9_122.jpg
# /kaggle/input/food11/validation/8_154.jpg
# /kaggle/input/food11/validation/1_74.jpg
# /kaggle/input/food11/validation/3_146.jpg
# /kaggle/input/food11/validation/9_294.jpg
# /kaggle/input/food11/validation/3_89.jpg
# /kaggle/input/food11/validation/8_33.jpg
# /kaggle/input/food11/validation/2_285.jpg
# /kaggle/input/food11/validation/2_447.jpg
# /kaggle/input/food11/validation/5_22.jpg
# /kaggle/input/food11/validation/10_218.jpg
# /kaggle/input/food11/validation/8_161.jpg
# /kaggle/input/food11/validation/2_26.jpg
# /kaggle/input/food11/validation/0_43.jpg
# /kaggle/input/food11/validation/3_163.jpg
# /kaggle/input/food11/validation/3_53.jpg
# /kaggle/input/food11/validation/9_411.jpg
# /kaggle/input/food11/validation/6_115.jpg
# /kaggle/input/food11/validation/10_5.jpg
# /kaggle/input/food11/validation/6_128.jpg
# /kaggle/input/food11/validation/2_382.jpg
# /kaggle/input/food11/validation/9_2.jpg
# /kaggle/input/food11/validation/9_348.jpg
# /kaggle/input/food11/validation/2_316.jpg
# /kaggle/input/food11/validation/9_317.jpg
# /kaggle/input/food11/validation/10_59.jpg
# /kaggle/input/food11/validation/4_52.jpg
# /kaggle/input/food11/validation/9_3.jpg
# /kaggle/input/food11/validation/0_36.jpg
# /kaggle/input/food11/validation/8_286.jpg
# /kaggle/input/food11/validation/3_20.jpg
# /kaggle/input/food11/validation/4_237.jpg
# /kaggle/input/food11/validation/2_384.jpg
# /kaggle/input/food11/validation/8_309.jpg
# /kaggle/input/food11/validation/5_148.jpg
# /kaggle/input/food11/validation/9_307.jpg
# /kaggle/input/food11/validation/9_184.jpg
# /kaggle/input/food11/validation/2_433.jpg
# /kaggle/input/food11/validation/1_90.jpg
# /kaggle/input/food11/validation/4_28.jpg
# /kaggle/input/food11/validation/2_200.jpg
# /kaggle/input/food11/validation/4_57.jpg
# /kaggle/input/food11/validation/0_180.jpg
# /kaggle/input/food11/validation/4_106.jpg
# /kaggle/input/food11/validation/0_285.jpg
# /kaggle/input/food11/validation/2_276.jpg
# /kaggle/input/food11/validation/0_92.jpg
# /kaggle/input/food11/validation/3_147.jpg
# /kaggle/input/food11/validation/10_37.jpg
# /kaggle/input/food11/validation/10_46.jpg
# /kaggle/input/food11/validation/9_486.jpg
# /kaggle/input/food11/validation/10_2.jpg
# /kaggle/input/food11/validation/2_495.jpg
# /kaggle/input/food11/validation/2_171.jpg
# /kaggle/input/food11/validation/8_239.jpg
# /kaggle/input/food11/validation/7_60.jpg
# /kaggle/input/food11/validation/0_106.jpg
# /kaggle/input/food11/validation/5_336.jpg
# /kaggle/input/food11/validation/7_79.jpg
# /kaggle/input/food11/validation/5_23.jpg
# /kaggle/input/food11/validation/2_305.jpg
# /kaggle/input/food11/validation/4_155.jpg
# /kaggle/input/food11/validation/5_197.jpg
# /kaggle/input/food11/validation/0_21.jpg
# /kaggle/input/food11/validation/2_203.jpg
# /kaggle/input/food11/validation/5_409.jpg
# /kaggle/input/food11/validation/0_359.jpg
# /kaggle/input/food11/validation/2_301.jpg
# /kaggle/input/food11/validation/4_321.jpg
# /kaggle/input/food11/validation/4_24.jpg
# /kaggle/input/food11/validation/8_297.jpg
# /kaggle/input/food11/validation/3_321.jpg
# /kaggle/input/food11/validation/2_37.jpg
# /kaggle/input/food11/validation/3_24.jpg
# /kaggle/input/food11/validation/4_151.jpg
# /kaggle/input/food11/validation/5_417.jpg
# /kaggle/input/food11/validation/6_131.jpg
# /kaggle/input/food11/validation/3_243.jpg
# /kaggle/input/food11/validation/8_198.jpg
# /kaggle/input/food11/validation/4_23.jpg
# /kaggle/input/food11/validation/9_86.jpg
# /kaggle/input/food11/validation/4_109.jpg
# /kaggle/input/food11/validation/7_89.jpg
# /kaggle/input/food11/validation/5_119.jpg
# /kaggle/input/food11/validation/4_265.jpg
# /kaggle/input/food11/validation/4_48.jpg
# /kaggle/input/food11/validation/3_318.jpg
# /kaggle/input/food11/validation/0_101.jpg
# /kaggle/input/food11/validation/0_105.jpg
# /kaggle/input/food11/validation/2_196.jpg
# /kaggle/input/food11/validation/5_123.jpg
# /kaggle/input/food11/validation/9_136.jpg
# /kaggle/input/food11/validation/4_188.jpg
# /kaggle/input/food11/validation/9_427.jpg
# /kaggle/input/food11/validation/2_371.jpg
# /kaggle/input/food11/validation/5_319.jpg
# /kaggle/input/food11/validation/3_71.jpg
# /kaggle/input/food11/validation/0_335.jpg
# /kaggle/input/food11/validation/0_265.jpg
# /kaggle/input/food11/validation/1_140.jpg
# /kaggle/input/food11/validation/8_243.jpg
# /kaggle/input/food11/validation/9_220.jpg
# /kaggle/input/food11/validation/10_16.jpg
# /kaggle/input/food11/validation/4_71.jpg
# /kaggle/input/food11/validation/7_87.jpg
# /kaggle/input/food11/validation/9_237.jpg
# /kaggle/input/food11/validation/10_181.jpg
# /kaggle/input/food11/validation/4_215.jpg
# /kaggle/input/food11/validation/9_346.jpg
# /kaggle/input/food11/validation/3_88.jpg
# /kaggle/input/food11/validation/7_54.jpg
# /kaggle/input/food11/validation/4_141.jpg
# /kaggle/input/food11/validation/10_172.jpg
# /kaggle/input/food11/validation/10_97.jpg
# /kaggle/input/food11/validation/8_328.jpg
# /kaggle/input/food11/validation/9_461.jpg
# /kaggle/input/food11/validation/8_84.jpg
# /kaggle/input/food11/validation/7_63.jpg
# /kaggle/input/food11/validation/8_127.jpg
# /kaggle/input/food11/validation/10_132.jpg
# /kaggle/input/food11/validation/5_431.jpg
# /kaggle/input/food11/validation/3_233.jpg
# /kaggle/input/food11/validation/9_229.jpg
# /kaggle/input/food11/validation/7_20.jpg
# /kaggle/input/food11/validation/2_52.jpg
# /kaggle/input/food11/validation/4_142.jpg
# /kaggle/input/food11/validation/5_135.jpg
# /kaggle/input/food11/validation/3_100.jpg
# /kaggle/input/food11/validation/5_186.jpg
# /kaggle/input/food11/validation/4_203.jpg
# /kaggle/input/food11/validation/6_36.jpg
# /kaggle/input/food11/validation/0_81.jpg
# /kaggle/input/food11/validation/3_300.jpg
# /kaggle/input/food11/validation/4_44.jpg
# /kaggle/input/food11/validation/5_111.jpg
# /kaggle/input/food11/validation/3_252.jpg
# /kaggle/input/food11/validation/7_45.jpg
# /kaggle/input/food11/validation/8_227.jpg
# /kaggle/input/food11/validation/0_338.jpg
# /kaggle/input/food11/validation/1_143.jpg
# /kaggle/input/food11/validation/9_483.jpg
# /kaggle/input/food11/validation/2_36.jpg
# /kaggle/input/food11/validation/8_314.jpg
# /kaggle/input/food11/validation/10_185.jpg
# /kaggle/input/food11/validation/9_121.jpg
# /kaggle/input/food11/validation/3_91.jpg
# /kaggle/input/food11/validation/9_118.jpg
# /kaggle/input/food11/validation/4_72.jpg
# /kaggle/input/food11/validation/9_21.jpg
# /kaggle/input/food11/validation/8_228.jpg
# /kaggle/input/food11/validation/0_4.jpg
# /kaggle/input/food11/validation/9_332.jpg
# /kaggle/input/food11/validation/8_281.jpg
# /kaggle/input/food11/validation/4_164.jpg
# /kaggle/input/food11/validation/2_496.jpg
# /kaggle/input/food11/validation/8_213.jpg
# /kaggle/input/food11/validation/3_72.jpg
# /kaggle/input/food11/validation/2_168.jpg
# /kaggle/input/food11/validation/6_68.jpg
# /kaggle/input/food11/validation/5_39.jpg
# /kaggle/input/food11/validation/4_1.jpg
# /kaggle/input/food11/validation/8_311.jpg
# /kaggle/input/food11/validation/4_144.jpg
# /kaggle/input/food11/validation/3_102.jpg
# /kaggle/input/food11/validation/9_8.jpg
# /kaggle/input/food11/validation/2_177.jpg
# /kaggle/input/food11/validation/4_153.jpg
# /kaggle/input/food11/validation/8_55.jpg
# /kaggle/input/food11/validation/5_260.jpg
# /kaggle/input/food11/validation/5_379.jpg
# /kaggle/input/food11/validation/9_318.jpg
# /kaggle/input/food11/validation/10_7.jpg
# /kaggle/input/food11/validation/8_168.jpg
# /kaggle/input/food11/validation/9_140.jpg
# /kaggle/input/food11/validation/0_123.jpg
# /kaggle/input/food11/validation/10_163.jpg
# /kaggle/input/food11/validation/6_29.jpg
# /kaggle/input/food11/validation/1_126.jpg
# /kaggle/input/food11/validation/1_135.jpg
# /kaggle/input/food11/validation/2_471.jpg
# /kaggle/input/food11/validation/9_304.jpg
# /kaggle/input/food11/validation/5_57.jpg
# /kaggle/input/food11/validation/9_413.jpg
# /kaggle/input/food11/validation/0_297.jpg
# /kaggle/input/food11/validation/2_199.jpg
# /kaggle/input/food11/validation/3_48.jpg
# /kaggle/input/food11/validation/2_47.jpg
# /kaggle/input/food11/validation/5_112.jpg
# /kaggle/input/food11/validation/5_447.jpg
# /kaggle/input/food11/validation/3_16.jpg
# /kaggle/input/food11/validation/5_121.jpg
# /kaggle/input/food11/validation/4_27.jpg
# /kaggle/input/food11/validation/5_1.jpg
# /kaggle/input/food11/validation/4_214.jpg
# /kaggle/input/food11/validation/9_431.jpg
# /kaggle/input/food11/validation/5_296.jpg
# /kaggle/input/food11/validation/2_403.jpg
# /kaggle/input/food11/validation/5_231.jpg
# /kaggle/input/food11/validation/9_14.jpg
# /kaggle/input/food11/validation/8_160.jpg
# /kaggle/input/food11/validation/2_376.jpg
# /kaggle/input/food11/validation/5_47.jpg
# /kaggle/input/food11/validation/3_236.jpg
# /kaggle/input/food11/validation/9_130.jpg
# /kaggle/input/food11/validation/4_197.jpg
# /kaggle/input/food11/validation/5_242.jpg
# /kaggle/input/food11/validation/5_270.jpg
# /kaggle/input/food11/validation/10_36.jpg
# /kaggle/input/food11/validation/8_12.jpg
# /kaggle/input/food11/validation/4_305.jpg
# /kaggle/input/food11/validation/9_177.jpg
# /kaggle/input/food11/validation/1_98.jpg
# /kaggle/input/food11/validation/3_76.jpg
# /kaggle/input/food11/validation/7_57.jpg
# /kaggle/input/food11/validation/7_15.jpg
# /kaggle/input/food11/validation/3_103.jpg
# /kaggle/input/food11/validation/5_160.jpg
# /kaggle/input/food11/validation/9_7.jpg
# /kaggle/input/food11/validation/8_108.jpg
# /kaggle/input/food11/validation/2_9.jpg
# /kaggle/input/food11/validation/8_236.jpg
# /kaggle/input/food11/validation/10_229.jpg
# /kaggle/input/food11/validation/8_294.jpg
# /kaggle/input/food11/validation/2_164.jpg
# /kaggle/input/food11/validation/0_311.jpg
# /kaggle/input/food11/validation/9_428.jpg
# /kaggle/input/food11/validation/9_453.jpg
# /kaggle/input/food11/validation/2_28.jpg
# /kaggle/input/food11/validation/7_71.jpg
# /kaggle/input/food11/validation/2_202.jpg
# /kaggle/input/food11/validation/9_451.jpg
# /kaggle/input/food11/validation/2_241.jpg
# /kaggle/input/food11/validation/5_436.jpg
# /kaggle/input/food11/validation/4_38.jpg
# /kaggle/input/food11/validation/5_377.jpg
# /kaggle/input/food11/validation/9_488.jpg
# /kaggle/input/food11/validation/5_272.jpg
# /kaggle/input/food11/validation/2_418.jpg
# /kaggle/input/food11/validation/9_99.jpg
# /kaggle/input/food11/validation/9_45.jpg
# /kaggle/input/food11/validation/0_260.jpg
# /kaggle/input/food11/validation/7_83.jpg
# /kaggle/input/food11/validation/6_143.jpg
# /kaggle/input/food11/validation/1_49.jpg
# /kaggle/input/food11/validation/5_229.jpg
# /kaggle/input/food11/validation/9_77.jpg
# /kaggle/input/food11/validation/5_290.jpg
# /kaggle/input/food11/validation/0_202.jpg
# /kaggle/input/food11/validation/4_93.jpg
# /kaggle/input/food11/validation/0_151.jpg
# /kaggle/input/food11/validation/10_231.jpg
# /kaggle/input/food11/validation/0_113.jpg
# /kaggle/input/food11/validation/2_414.jpg
# /kaggle/input/food11/validation/10_31.jpg
# /kaggle/input/food11/validation/4_159.jpg
# /kaggle/input/food11/validation/3_30.jpg
# /kaggle/input/food11/validation/8_35.jpg
# /kaggle/input/food11/validation/10_123.jpg
# /kaggle/input/food11/validation/9_275.jpg
# /kaggle/input/food11/validation/2_498.jpg
# /kaggle/input/food11/validation/2_494.jpg
# /kaggle/input/food11/validation/9_470.jpg
# /kaggle/input/food11/validation/0_323.jpg
# /kaggle/input/food11/validation/5_243.jpg
# /kaggle/input/food11/validation/4_226.jpg
# /kaggle/input/food11/validation/6_100.jpg
# /kaggle/input/food11/validation/5_204.jpg
# /kaggle/input/food11/validation/9_460.jpg
# /kaggle/input/food11/validation/4_125.jpg
# /kaggle/input/food11/validation/1_9.jpg
# /kaggle/input/food11/validation/3_203.jpg
# /kaggle/input/food11/validation/0_95.jpg
# /kaggle/input/food11/validation/2_99.jpg
# /kaggle/input/food11/validation/5_75.jpg
# /kaggle/input/food11/validation/1_16.jpg
# /kaggle/input/food11/validation/9_425.jpg
# /kaggle/input/food11/validation/8_242.jpg
# /kaggle/input/food11/validation/9_19.jpg
# /kaggle/input/food11/validation/5_415.jpg
# /kaggle/input/food11/validation/0_182.jpg
# /kaggle/input/food11/validation/5_16.jpg
# /kaggle/input/food11/validation/2_484.jpg
# /kaggle/input/food11/validation/9_41.jpg
# /kaggle/input/food11/validation/3_121.jpg
# /kaggle/input/food11/validation/5_347.jpg
# /kaggle/input/food11/validation/3_215.jpg
# /kaggle/input/food11/validation/8_346.jpg
# /kaggle/input/food11/validation/9_150.jpg
# /kaggle/input/food11/validation/9_206.jpg
# /kaggle/input/food11/validation/8_93.jpg
# /kaggle/input/food11/validation/9_234.jpg
# /kaggle/input/food11/validation/10_131.jpg
# /kaggle/input/food11/validation/2_45.jpg
# /kaggle/input/food11/validation/5_218.jpg
# /kaggle/input/food11/validation/4_102.jpg
# /kaggle/input/food11/validation/9_20.jpg
# /kaggle/input/food11/validation/9_388.jpg
# /kaggle/input/food11/validation/5_343.jpg
# /kaggle/input/food11/validation/8_335.jpg
# /kaggle/input/food11/validation/1_20.jpg
# /kaggle/input/food11/validation/2_277.jpg
# /kaggle/input/food11/validation/5_301.jpg
# /kaggle/input/food11/validation/9_207.jpg
# /kaggle/input/food11/validation/8_2.jpg
# /kaggle/input/food11/validation/5_324.jpg
# /kaggle/input/food11/validation/2_416.jpg
# /kaggle/input/food11/validation/10_214.jpg
# /kaggle/input/food11/validation/5_150.jpg
# /kaggle/input/food11/validation/1_94.jpg
# /kaggle/input/food11/validation/9_4.jpg
# /kaggle/input/food11/validation/4_195.jpg
# /kaggle/input/food11/validation/8_298.jpg
# /kaggle/input/food11/validation/8_29.jpg
# /kaggle/input/food11/validation/5_102.jpg
# /kaggle/input/food11/validation/0_124.jpg
# /kaggle/input/food11/validation/2_39.jpg
# /kaggle/input/food11/validation/3_180.jpg
# /kaggle/input/food11/validation/9_168.jpg
# /kaggle/input/food11/validation/3_314.jpg
# /kaggle/input/food11/validation/10_193.jpg
# /kaggle/input/food11/validation/3_256.jpg
# /kaggle/input/food11/validation/9_56.jpg
# /kaggle/input/food11/validation/5_249.jpg
# /kaggle/input/food11/validation/2_84.jpg
# /kaggle/input/food11/validation/2_86.jpg
# /kaggle/input/food11/validation/8_287.jpg
# /kaggle/input/food11/validation/9_83.jpg
# /kaggle/input/food11/validation/4_300.jpg
# /kaggle/input/food11/validation/0_11.jpg
# /kaggle/input/food11/validation/8_170.jpg
# /kaggle/input/food11/validation/8_305.jpg
# /kaggle/input/food11/validation/5_181.jpg
# /kaggle/input/food11/validation/0_121.jpg
# /kaggle/input/food11/validation/8_47.jpg
# /kaggle/input/food11/validation/6_138.jpg
# /kaggle/input/food11/validation/8_194.jpg
# /kaggle/input/food11/validation/7_37.jpg
# /kaggle/input/food11/validation/2_55.jpg
# /kaggle/input/food11/validation/0_100.jpg
# /kaggle/input/food11/validation/6_145.jpg
# /kaggle/input/food11/validation/1_4.jpg
# /kaggle/input/food11/validation/6_130.jpg
# /kaggle/input/food11/validation/8_337.jpg
# /kaggle/input/food11/validation/7_51.jpg
# /kaggle/input/food11/validation/8_183.jpg
# /kaggle/input/food11/validation/0_183.jpg
# /kaggle/input/food11/validation/6_112.jpg
# /kaggle/input/food11/validation/3_68.jpg
# /kaggle/input/food11/validation/10_110.jpg
# /kaggle/input/food11/validation/8_19.jpg
# /kaggle/input/food11/validation/8_219.jpg
# /kaggle/input/food11/validation/7_21.jpg
# /kaggle/input/food11/validation/3_36.jpg
# /kaggle/input/food11/validation/3_83.jpg
# /kaggle/input/food11/validation/7_11.jpg
# /kaggle/input/food11/validation/8_249.jpg
# /kaggle/input/food11/validation/4_176.jpg
# /kaggle/input/food11/validation/6_105.jpg
# /kaggle/input/food11/validation/1_92.jpg
# /kaggle/input/food11/validation/3_15.jpg
# /kaggle/input/food11/validation/10_9.jpg
# /kaggle/input/food11/validation/3_317.jpg
# /kaggle/input/food11/validation/0_200.jpg
# /kaggle/input/food11/validation/5_177.jpg
# /kaggle/input/food11/validation/3_111.jpg
# /kaggle/input/food11/validation/8_126.jpg
# /kaggle/input/food11/validation/1_41.jpg
# /kaggle/input/food11/validation/0_150.jpg
# /kaggle/input/food11/validation/2_350.jpg
# /kaggle/input/food11/validation/3_115.jpg
# /kaggle/input/food11/validation/2_2.jpg
# /kaggle/input/food11/validation/4_196.jpg
# /kaggle/input/food11/validation/9_67.jpg
# /kaggle/input/food11/validation/9_395.jpg
# /kaggle/input/food11/validation/3_275.jpg
# /kaggle/input/food11/validation/4_51.jpg
# /kaggle/input/food11/validation/2_337.jpg
# /kaggle/input/food11/validation/2_72.jpg
# /kaggle/input/food11/validation/2_124.jpg
# /kaggle/input/food11/validation/10_51.jpg
# /kaggle/input/food11/validation/8_104.jpg
# /kaggle/input/food11/validation/3_75.jpg
# /kaggle/input/food11/validation/9_176.jpg
# /kaggle/input/food11/validation/7_40.jpg
# /kaggle/input/food11/validation/2_295.jpg
# /kaggle/input/food11/validation/9_96.jpg
# /kaggle/input/food11/validation/6_14.jpg
# /kaggle/input/food11/validation/6_53.jpg
# /kaggle/input/food11/validation/9_262.jpg
# /kaggle/input/food11/validation/1_10.jpg
# /kaggle/input/food11/validation/2_278.jpg
# /kaggle/input/food11/validation/10_107.jpg
# /kaggle/input/food11/validation/5_61.jpg
# /kaggle/input/food11/validation/1_78.jpg
# /kaggle/input/food11/validation/2_51.jpg
# /kaggle/input/food11/validation/0_48.jpg
# /kaggle/input/food11/validation/10_38.jpg
# /kaggle/input/food11/validation/9_286.jpg
# /kaggle/input/food11/validation/9_336.jpg
# /kaggle/input/food11/validation/4_124.jpg
# /kaggle/input/food11/validation/10_1.jpg
# /kaggle/input/food11/validation/5_149.jpg
# /kaggle/input/food11/validation/0_288.jpg
# /kaggle/input/food11/validation/1_142.jpg
# /kaggle/input/food11/validation/5_297.jpg
# /kaggle/input/food11/validation/2_184.jpg
# /kaggle/input/food11/validation/9_144.jpg
# /kaggle/input/food11/validation/0_178.jpg
# /kaggle/input/food11/validation/3_320.jpg
# /kaggle/input/food11/validation/9_433.jpg
# /kaggle/input/food11/validation/2_5.jpg
# /kaggle/input/food11/validation/7_64.jpg
# /kaggle/input/food11/validation/8_79.jpg
# /kaggle/input/food11/validation/0_132.jpg
# /kaggle/input/food11/validation/0_143.jpg
# /kaggle/input/food11/validation/4_136.jpg
# /kaggle/input/food11/validation/7_92.jpg
# /kaggle/input/food11/validation/3_229.jpg
# /kaggle/input/food11/validation/3_279.jpg
# /kaggle/input/food11/validation/8_251.jpg
# /kaggle/input/food11/validation/2_83.jpg
# /kaggle/input/food11/validation/6_11.jpg
# /kaggle/input/food11/validation/10_4.jpg
# /kaggle/input/food11/validation/9_201.jpg
# /kaggle/input/food11/validation/8_125.jpg
# /kaggle/input/food11/validation/2_191.jpg
# /kaggle/input/food11/validation/2_297.jpg
# /kaggle/input/food11/validation/4_128.jpg
# /kaggle/input/food11/validation/4_119.jpg
# /kaggle/input/food11/validation/8_276.jpg
# /kaggle/input/food11/validation/3_258.jpg
# /kaggle/input/food11/validation/2_112.jpg
# /kaggle/input/food11/validation/0_119.jpg
# /kaggle/input/food11/validation/3_37.jpg
# /kaggle/input/food11/validation/2_44.jpg
# /kaggle/input/food11/validation/5_286.jpg
# /kaggle/input/food11/validation/5_180.jpg
# /kaggle/input/food11/validation/9_145.jpg
# /kaggle/input/food11/validation/2_461.jpg
# /kaggle/input/food11/validation/5_4.jpg
# /kaggle/input/food11/validation/9_389.jpg
# /kaggle/input/food11/validation/9_316.jpg
# /kaggle/input/food11/validation/8_0.jpg
# /kaggle/input/food11/validation/3_231.jpg
# /kaggle/input/food11/validation/2_450.jpg
# /kaggle/input/food11/validation/0_203.jpg
# /kaggle/input/food11/validation/9_392.jpg
# /kaggle/input/food11/validation/5_157.jpg
# /kaggle/input/food11/validation/10_20.jpg
# /kaggle/input/food11/validation/3_29.jpg
# /kaggle/input/food11/validation/6_51.jpg
# /kaggle/input/food11/validation/9_131.jpg
# /kaggle/input/food11/validation/1_63.jpg
# /kaggle/input/food11/validation/9_225.jpg
# /kaggle/input/food11/validation/5_332.jpg
# /kaggle/input/food11/validation/10_91.jpg
# /kaggle/input/food11/validation/9_221.jpg
# /kaggle/input/food11/validation/0_46.jpg
# /kaggle/input/food11/validation/2_71.jpg
# /kaggle/input/food11/validation/10_54.jpg
# /kaggle/input/food11/validation/2_313.jpg
# /kaggle/input/food11/validation/4_32.jpg
# /kaggle/input/food11/validation/4_252.jpg
# /kaggle/input/food11/validation/8_313.jpg
# /kaggle/input/food11/validation/9_462.jpg
# /kaggle/input/food11/validation/5_304.jpg
# /kaggle/input/food11/validation/0_73.jpg
# /kaggle/input/food11/validation/8_92.jpg
# /kaggle/input/food11/validation/8_58.jpg
# /kaggle/input/food11/validation/9_454.jpg
# /kaggle/input/food11/validation/1_18.jpg
# /kaggle/input/food11/validation/1_83.jpg
# /kaggle/input/food11/validation/7_75.jpg
# /kaggle/input/food11/validation/9_331.jpg
# /kaggle/input/food11/validation/0_298.jpg
# /kaggle/input/food11/validation/5_18.jpg
# /kaggle/input/food11/validation/9_186.jpg
# /kaggle/input/food11/validation/8_307.jpg
# /kaggle/input/food11/validation/9_162.jpg
# /kaggle/input/food11/validation/0_294.jpg
# /kaggle/input/food11/validation/9_449.jpg
# /kaggle/input/food11/validation/1_29.jpg
# /kaggle/input/food11/validation/8_240.jpg
# /kaggle/input/food11/validation/0_219.jpg
# /kaggle/input/food11/validation/4_161.jpg
# /kaggle/input/food11/validation/0_13.jpg
# /kaggle/input/food11/validation/0_12.jpg
# /kaggle/input/food11/validation/3_315.jpg
# /kaggle/input/food11/validation/0_195.jpg
# /kaggle/input/food11/validation/5_207.jpg
# ...
# /kaggle/input/food11/food-11/evaluation/3_283.jpg
# /kaggle/input/food11/food-11/evaluation/3_237.jpg
# /kaggle/input/food11/food-11/evaluation/9_308.jpg
# /kaggle/input/food11/food-11/evaluation/6_98.jpg
# /kaggle/input/food11/food-11/evaluation/8_128.jpg
# /kaggle/input/food11/food-11/evaluation/0_271.jpg
# /kaggle/input/food11/food-11/evaluation/10_95.jpg
# /kaggle/input/food11/food-11/evaluation/4_274.jpg
# /kaggle/input/food11/food-11/evaluation/0_207.jpg
# /kaggle/input/food11/food-11/evaluation/10_137.jpg
# /kaggle/input/food11/food-11/evaluation/5_144.jpg
# /kaggle/input/food11/food-11/evaluation/6_86.jpg
# /kaggle/input/food11/food-11/evaluation/1_116.jpg
# /kaggle/input/food11/food-11/evaluation/2_304.jpg
# /kaggle/input/food11/food-11/evaluation/5_116.jpg
# /kaggle/input/food11/food-11/evaluation/9_272.jpg
# /kaggle/input/food11/food-11/evaluation/9_372.jpg
# /kaggle/input/food11/food-11/evaluation/9_183.jpg
# /kaggle/input/food11/food-11/evaluation/10_62.jpg
# /kaggle/input/food11/food-11/evaluation/0_365.jpg
# /kaggle/input/food11/food-11/evaluation/0_44.jpg
# /kaggle/input/food11/food-11/evaluation/8_224.jpg
# /kaggle/input/food11/food-11/evaluation/0_79.jpg
# /kaggle/input/food11/food-11/evaluation/4_234.jpg
# /kaggle/input/food11/food-11/evaluation/0_142.jpg
# /kaggle/input/food11/food-11/evaluation/9_94.jpg
# /kaggle/input/food11/food-11/evaluation/3_40.jpg
# /kaggle/input/food11/food-11/evaluation/5_44.jpg
# /kaggle/input/food11/food-11/evaluation/1_145.jpg
# /kaggle/input/food11/food-11/evaluation/2_369.jpg
# /kaggle/input/food11/food-11/evaluation/8_106.jpg
# /kaggle/input/food11/food-11/evaluation/2_488.jpg
# /kaggle/input/food11/food-11/evaluation/6_142.jpg
# /kaggle/input/food11/food-11/evaluation/10_220.jpg
# /kaggle/input/food11/food-11/evaluation/4_76.jpg
# /kaggle/input/food11/food-11/evaluation/6_66.jpg
# /kaggle/input/food11/food-11/evaluation/3_116.jpg
# /kaggle/input/food11/food-11/evaluation/5_384.jpg
# /kaggle/input/food11/food-11/evaluation/2_1.jpg
# /kaggle/input/food11/food-11/evaluation/9_467.jpg
# /kaggle/input/food11/food-11/evaluation/4_201.jpg
# /kaggle/input/food11/food-11/evaluation/9_264.jpg
# /kaggle/input/food11/food-11/evaluation/2_469.jpg
# /kaggle/input/food11/food-11/evaluation/10_41.jpg
# /kaggle/input/food11/food-11/evaluation/9_338.jpg
# /kaggle/input/food11/food-11/evaluation/0_166.jpg
# /kaggle/input/food11/food-11/evaluation/8_178.jpg
# /kaggle/input/food11/food-11/evaluation/4_67.jpg
# /kaggle/input/food11/food-11/evaluation/6_22.jpg
# /kaggle/input/food11/food-11/evaluation/5_26.jpg
# /kaggle/input/food11/food-11/evaluation/9_226.jpg
# /kaggle/input/food11/food-11/evaluation/9_69.jpg
# /kaggle/input/food11/food-11/evaluation/4_40.jpg
# /kaggle/input/food11/food-11/evaluation/10_179.jpg
# /kaggle/input/food11/food-11/evaluation/1_146.jpg
# /kaggle/input/food11/food-11/evaluation/3_47.jpg
# /kaggle/input/food11/food-11/evaluation/3_307.jpg
# /kaggle/input/food11/food-11/evaluation/3_6.jpg
# /kaggle/input/food11/food-11/evaluation/9_447.jpg
# /kaggle/input/food11/food-11/evaluation/10_56.jpg
# /kaggle/input/food11/food-11/evaluation/4_73.jpg
# /kaggle/input/food11/food-11/evaluation/6_107.jpg
# /kaggle/input/food11/food-11/evaluation/4_244.jpg
# /kaggle/input/food11/food-11/evaluation/3_45.jpg
# /kaggle/input/food11/food-11/evaluation/9_499.jpg
# /kaggle/input/food11/food-11/evaluation/9_252.jpg
# /kaggle/input/food11/food-11/evaluation/5_329.jpg
# /kaggle/input/food11/food-11/evaluation/9_410.jpg
# /kaggle/input/food11/food-11/evaluation/5_185.jpg
# /kaggle/input/food11/food-11/evaluation/1_115.jpg
# /kaggle/input/food11/food-11/evaluation/1_120.jpg
# /kaggle/input/food11/food-11/evaluation/3_201.jpg
# /kaggle/input/food11/food-11/evaluation/8_83.jpg
# /kaggle/input/food11/food-11/evaluation/9_437.jpg
# /kaggle/input/food11/food-11/evaluation/4_5.jpg
# /kaggle/input/food11/food-11/evaluation/9_224.jpg
# /kaggle/input/food11/food-11/evaluation/3_60.jpg
# /kaggle/input/food11/food-11/evaluation/5_261.jpg
# /kaggle/input/food11/food-11/evaluation/1_130.jpg
# /kaggle/input/food11/food-11/evaluation/9_148.jpg
# /kaggle/input/food11/food-11/evaluation/5_407.jpg
# /kaggle/input/food11/food-11/evaluation/5_381.jpg
# /kaggle/input/food11/food-11/evaluation/3_240.jpg
# /kaggle/input/food11/food-11/evaluation/8_215.jpg
# /kaggle/input/food11/food-11/evaluation/2_342.jpg
# /kaggle/input/food11/food-11/evaluation/3_294.jpg
# /kaggle/input/food11/food-11/evaluation/5_5.jpg
# /kaggle/input/food11/food-11/evaluation/0_319.jpg
# /kaggle/input/food11/food-11/evaluation/3_230.jpg
# /kaggle/input/food11/food-11/evaluation/9_394.jpg
# /kaggle/input/food11/food-11/evaluation/9_344.jpg
# /kaggle/input/food11/food-11/evaluation/7_53.jpg
# /kaggle/input/food11/food-11/evaluation/5_103.jpg
# /kaggle/input/food11/food-11/evaluation/8_14.jpg
# /kaggle/input/food11/food-11/evaluation/0_163.jpg
# /kaggle/input/food11/food-11/evaluation/8_280.jpg
# /kaggle/input/food11/food-11/evaluation/9_255.jpg
# /kaggle/input/food11/food-11/evaluation/3_232.jpg
# /kaggle/input/food11/food-11/evaluation/4_210.jpg
# /kaggle/input/food11/food-11/evaluation/2_133.jpg
# /kaggle/input/food11/food-11/evaluation/9_258.jpg
# /kaggle/input/food11/food-11/evaluation/2_357.jpg
# /kaggle/input/food11/food-11/evaluation/4_223.jpg
# /kaggle/input/food11/food-11/evaluation/2_331.jpg
# /kaggle/input/food11/food-11/evaluation/5_274.jpg
# /kaggle/input/food11/food-11/evaluation/9_50.jpg
# /kaggle/input/food11/food-11/evaluation/8_131.jpg
# /kaggle/input/food11/food-11/evaluation/9_396.jpg
# /kaggle/input/food11/food-11/evaluation/5_56.jpg
# /kaggle/input/food11/food-11/evaluation/2_146.jpg
# /kaggle/input/food11/food-11/evaluation/3_148.jpg
# /kaggle/input/food11/food-11/evaluation/5_305.jpg
# /kaggle/input/food11/food-11/evaluation/5_248.jpg
# /kaggle/input/food11/food-11/evaluation/4_160.jpg
# /kaggle/input/food11/food-11/evaluation/9_16.jpg
# /kaggle/input/food11/food-11/evaluation/5_27.jpg
# /kaggle/input/food11/food-11/evaluation/9_464.jpg
# /kaggle/input/food11/food-11/evaluation/9_441.jpg
# /kaggle/input/food11/food-11/evaluation/9_491.jpg
# /kaggle/input/food11/food-11/evaluation/3_167.jpg
# /kaggle/input/food11/food-11/evaluation/2_286.jpg
# /kaggle/input/food11/food-11/evaluation/3_9.jpg
# /kaggle/input/food11/food-11/evaluation/5_139.jpg
# /kaggle/input/food11/food-11/evaluation/1_111.jpg
# /kaggle/input/food11/food-11/evaluation/9_187.jpg
# /kaggle/input/food11/food-11/evaluation/9_402.jpg
# /kaggle/input/food11/food-11/evaluation/5_401.jpg
# /kaggle/input/food11/food-11/evaluation/9_213.jpg
# /kaggle/input/food11/food-11/evaluation/6_69.jpg
# /kaggle/input/food11/food-11/evaluation/8_117.jpg
# /kaggle/input/food11/food-11/evaluation/0_241.jpg
# /kaggle/input/food11/food-11/evaluation/8_30.jpg
# /kaggle/input/food11/food-11/evaluation/2_193.jpg
# /kaggle/input/food11/food-11/evaluation/1_24.jpg
# /kaggle/input/food11/food-11/evaluation/0_145.jpg
# /kaggle/input/food11/food-11/evaluation/3_166.jpg
# /kaggle/input/food11/food-11/evaluation/9_398.jpg
# /kaggle/input/food11/food-11/evaluation/8_34.jpg
# /kaggle/input/food11/food-11/evaluation/9_154.jpg
# /kaggle/input/food11/food-11/evaluation/3_38.jpg
# /kaggle/input/food11/food-11/evaluation/3_35.jpg
# /kaggle/input/food11/food-11/evaluation/5_412.jpg
# /kaggle/input/food11/food-11/evaluation/7_16.jpg
# /kaggle/input/food11/food-11/evaluation/6_13.jpg
# /kaggle/input/food11/food-11/evaluation/0_224.jpg
# /kaggle/input/food11/food-11/evaluation/3_8.jpg
# /kaggle/input/food11/food-11/evaluation/2_329.jpg
# /kaggle/input/food11/food-11/evaluation/4_193.jpg
# /kaggle/input/food11/food-11/evaluation/2_114.jpg
# /kaggle/input/food11/food-11/evaluation/6_134.jpg
# /kaggle/input/food11/food-11/evaluation/8_291.jpg
# /kaggle/input/food11/food-11/evaluation/2_412.jpg
# /kaggle/input/food11/food-11/evaluation/9_409.jpg
# /kaggle/input/food11/food-11/evaluation/8_184.jpg
# /kaggle/input/food11/food-11/evaluation/2_335.jpg
# /kaggle/input/food11/food-11/evaluation/6_74.jpg
# /kaggle/input/food11/food-11/evaluation/9_197.jpg
# /kaggle/input/food11/food-11/evaluation/9_178.jpg
# /kaggle/input/food11/food-11/evaluation/2_467.jpg
# /kaggle/input/food11/food-11/evaluation/5_327.jpg
# /kaggle/input/food11/food-11/evaluation/0_136.jpg
# /kaggle/input/food11/food-11/evaluation/5_257.jpg
# /kaggle/input/food11/food-11/evaluation/8_62.jpg
# /kaggle/input/food11/food-11/evaluation/9_126.jpg
# /kaggle/input/food11/food-11/evaluation/9_134.jpg
# /kaggle/input/food11/food-11/evaluation/2_339.jpg
# /kaggle/input/food11/food-11/evaluation/9_189.jpg
# /kaggle/input/food11/food-11/evaluation/1_128.jpg
# /kaggle/input/food11/food-11/evaluation/4_61.jpg
# /kaggle/input/food11/food-11/evaluation/0_110.jpg
# /kaggle/input/food11/food-11/evaluation/4_68.jpg
# /kaggle/input/food11/food-11/evaluation/3_276.jpg
# /kaggle/input/food11/food-11/evaluation/9_30.jpg
# /kaggle/input/food11/food-11/evaluation/5_83.jpg
# /kaggle/input/food11/food-11/evaluation/9_325.jpg
# /kaggle/input/food11/food-11/evaluation/10_43.jpg
# /kaggle/input/food11/food-11/evaluation/5_420.jpg
# /kaggle/input/food11/food-11/evaluation/2_492.jpg
# /kaggle/input/food11/food-11/evaluation/9_23.jpg
# /kaggle/input/food11/food-11/evaluation/10_116.jpg
# /kaggle/input/food11/food-11/evaluation/0_264.jpg
# /kaggle/input/food11/food-11/evaluation/10_226.jpg
# /kaggle/input/food11/food-11/evaluation/9_105.jpg
# /kaggle/input/food11/food-11/evaluation/8_17.jpg
# /kaggle/input/food11/food-11/evaluation/5_7.jpg
# /kaggle/input/food11/food-11/evaluation/9_471.jpg
# /kaggle/input/food11/food-11/evaluation/9_241.jpg
# /kaggle/input/food11/food-11/evaluation/7_58.jpg
# /kaggle/input/food11/food-11/evaluation/2_269.jpg
# /kaggle/input/food11/food-11/evaluation/5_214.jpg
# /kaggle/input/food11/food-11/evaluation/1_48.jpg
# /kaggle/input/food11/food-11/evaluation/2_49.jpg
# /kaggle/input/food11/food-11/evaluation/6_39.jpg
# /kaggle/input/food11/food-11/evaluation/6_31.jpg
# /kaggle/input/food11/food-11/evaluation/0_339.jpg
# /kaggle/input/food11/food-11/evaluation/2_387.jpg
# /kaggle/input/food11/food-11/evaluation/10_187.jpg
# /kaggle/input/food11/food-11/evaluation/9_163.jpg
# /kaggle/input/food11/food-11/evaluation/9_155.jpg
# /kaggle/input/food11/food-11/evaluation/8_24.jpg
# /kaggle/input/food11/food-11/evaluation/4_172.jpg
# /kaggle/input/food11/food-11/evaluation/4_225.jpg
# /kaggle/input/food11/food-11/evaluation/9_33.jpg
# /kaggle/input/food11/food-11/evaluation/8_270.jpg
# /kaggle/input/food11/food-11/evaluation/4_62.jpg
# /kaggle/input/food11/food-11/evaluation/4_286.jpg
# /kaggle/input/food11/food-11/evaluation/2_143.jpg
# /kaggle/input/food11/food-11/evaluation/9_232.jpg
# /kaggle/input/food11/food-11/evaluation/8_226.jpg
# /kaggle/input/food11/food-11/evaluation/5_349.jpg
# /kaggle/input/food11/food-11/evaluation/0_250.jpg
# /kaggle/input/food11/food-11/evaluation/8_192.jpg
# /kaggle/input/food11/food-11/evaluation/2_0.jpg
# /kaggle/input/food11/food-11/evaluation/10_0.jpg
# /kaggle/input/food11/food-11/evaluation/3_334.jpg
# /kaggle/input/food11/food-11/evaluation/8_115.jpg
# /kaggle/input/food11/food-11/evaluation/2_291.jpg
# /kaggle/input/food11/food-11/evaluation/5_209.jpg
# /kaggle/input/food11/food-11/evaluation/9_135.jpg
# /kaggle/input/food11/food-11/evaluation/1_34.jpg
# /kaggle/input/food11/food-11/evaluation/9_498.jpg
# /kaggle/input/food11/food-11/evaluation/8_49.jpg
# /kaggle/input/food11/food-11/evaluation/3_309.jpg
# /kaggle/input/food11/food-11/evaluation/3_65.jpg
# /kaggle/input/food11/food-11/evaluation/0_146.jpg
# /kaggle/input/food11/food-11/evaluation/9_415.jpg
# /kaggle/input/food11/food-11/evaluation/9_463.jpg
# /kaggle/input/food11/food-11/evaluation/0_23.jpg
# /kaggle/input/food11/food-11/evaluation/3_34.jpg
# /kaggle/input/food11/food-11/evaluation/0_351.jpg
# /kaggle/input/food11/food-11/evaluation/5_307.jpg
# /kaggle/input/food11/food-11/evaluation/8_263.jpg
# /kaggle/input/food11/food-11/evaluation/9_385.jpg
# /kaggle/input/food11/food-11/evaluation/5_282.jpg
# /kaggle/input/food11/food-11/evaluation/2_393.jpg
# /kaggle/input/food11/food-11/evaluation/2_440.jpg
# /kaggle/input/food11/food-11/evaluation/8_193.jpg
# /kaggle/input/food11/food-11/evaluation/0_173.jpg
# /kaggle/input/food11/food-11/evaluation/0_318.jpg
# /kaggle/input/food11/food-11/evaluation/10_156.jpg
# /kaggle/input/food11/food-11/evaluation/1_119.jpg
# /kaggle/input/food11/food-11/evaluation/7_55.jpg
# /kaggle/input/food11/food-11/evaluation/4_200.jpg
# /kaggle/input/food11/food-11/evaluation/8_283.jpg
# /kaggle/input/food11/food-11/evaluation/8_87.jpg
# /kaggle/input/food11/food-11/evaluation/0_172.jpg
# /kaggle/input/food11/food-11/evaluation/8_143.jpg
# /kaggle/input/food11/food-11/evaluation/1_44.jpg
# /kaggle/input/food11/food-11/evaluation/9_370.jpg
# /kaggle/input/food11/food-11/evaluation/9_296.jpg
# /kaggle/input/food11/food-11/evaluation/8_74.jpg
# /kaggle/input/food11/food-11/evaluation/5_152.jpg
# /kaggle/input/food11/food-11/evaluation/2_40.jpg
# /kaggle/input/food11/food-11/evaluation/3_293.jpg
# /kaggle/input/food11/food-11/evaluation/8_265.jpg
# /kaggle/input/food11/food-11/evaluation/5_422.jpg
# /kaggle/input/food11/food-11/evaluation/3_209.jpg
# /kaggle/input/food11/food-11/evaluation/0_157.jpg
# /kaggle/input/food11/food-11/evaluation/4_13.jpg
# /kaggle/input/food11/food-11/evaluation/9_468.jpg
# /kaggle/input/food11/food-11/evaluation/2_23.jpg
# /kaggle/input/food11/food-11/evaluation/6_81.jpg
# /kaggle/input/food11/food-11/evaluation/10_87.jpg
# /kaggle/input/food11/food-11/evaluation/0_252.jpg
# /kaggle/input/food11/food-11/evaluation/2_113.jpg
# /kaggle/input/food11/food-11/evaluation/0_233.jpg
# /kaggle/input/food11/food-11/evaluation/10_102.jpg
# /kaggle/input/food11/food-11/evaluation/9_11.jpg
# /kaggle/input/food11/food-11/evaluation/0_205.jpg
# /kaggle/input/food11/food-11/evaluation/9_330.jpg
# /kaggle/input/food11/food-11/evaluation/7_38.jpg
# /kaggle/input/food11/food-11/evaluation/1_21.jpg
# /kaggle/input/food11/food-11/evaluation/10_169.jpg
# /kaggle/input/food11/food-11/evaluation/2_448.jpg
# /kaggle/input/food11/food-11/evaluation/9_52.jpg
# /kaggle/input/food11/food-11/evaluation/3_21.jpg
# /kaggle/input/food11/food-11/evaluation/3_250.jpg
# /kaggle/input/food11/food-11/evaluation/4_156.jpg
# /kaggle/input/food11/food-11/evaluation/9_253.jpg
# /kaggle/input/food11/food-11/evaluation/9_445.jpg
# /kaggle/input/food11/food-11/evaluation/9_390.jpg
# /kaggle/input/food11/food-11/evaluation/2_131.jpg
# /kaggle/input/food11/food-11/evaluation/0_223.jpg
# /kaggle/input/food11/food-11/evaluation/4_248.jpg
# /kaggle/input/food11/food-11/evaluation/3_81.jpg
# /kaggle/input/food11/food-11/evaluation/5_414.jpg
# /kaggle/input/food11/food-11/evaluation/9_261.jpg
# /kaggle/input/food11/food-11/evaluation/0_68.jpg
# /kaggle/input/food11/food-11/evaluation/2_166.jpg
# /kaggle/input/food11/food-11/evaluation/3_64.jpg
# /kaggle/input/food11/food-11/evaluation/0_158.jpg
# /kaggle/input/food11/food-11/evaluation/8_67.jpg
# /kaggle/input/food11/food-11/evaluation/2_110.jpg
# /kaggle/input/food11/food-11/evaluation/5_316.jpg
# /kaggle/input/food11/food-11/evaluation/0_227.jpg
# /kaggle/input/food11/food-11/evaluation/0_35.jpg
# /kaggle/input/food11/food-11/evaluation/10_71.jpg
# /kaggle/input/food11/food-11/evaluation/2_332.jpg
# /kaggle/input/food11/food-11/evaluation/10_100.jpg
# /kaggle/input/food11/food-11/evaluation/2_130.jpg
# /kaggle/input/food11/food-11/evaluation/2_147.jpg
# /kaggle/input/food11/food-11/evaluation/0_108.jpg
# /kaggle/input/food11/food-11/evaluation/5_2.jpg
# /kaggle/input/food11/food-11/evaluation/3_87.jpg
# /kaggle/input/food11/food-11/evaluation/1_33.jpg
# /kaggle/input/food11/food-11/evaluation/3_219.jpg
# /kaggle/input/food11/food-11/evaluation/8_271.jpg
# /kaggle/input/food11/food-11/evaluation/8_295.jpg
# /kaggle/input/food11/food-11/evaluation/2_87.jpg
# /kaggle/input/food11/food-11/evaluation/9_180.jpg
# /kaggle/input/food11/food-11/evaluation/3_62.jpg
# /kaggle/input/food11/food-11/evaluation/9_100.jpg
# /kaggle/input/food11/food-11/evaluation/0_367.jpg
# /kaggle/input/food11/food-11/evaluation/2_359.jpg
# /kaggle/input/food11/food-11/evaluation/0_10.jpg
# /kaggle/input/food11/food-11/evaluation/5_80.jpg
# /kaggle/input/food11/food-11/evaluation/2_174.jpg
# /kaggle/input/food11/food-11/evaluation/2_77.jpg
# /kaggle/input/food11/food-11/evaluation/1_28.jpg
# /kaggle/input/food11/food-11/evaluation/7_13.jpg
# /kaggle/input/food11/food-11/evaluation/10_170.jpg

# %% [markdown]
# ### Importing the libraries

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset ,DataLoader
from sklearn.model_selection import train_test_split
import os
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_dir="/kaggle/input/food11/training"
test_dir="/kaggle/input/food11/evaluation"
val_dir="/kaggle/input/food11/validation"
img_size=(224,224)
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class food(Dataset):
    def __init__(self,images,img_size,transform=None):
        super().__init__()
        self.img_size=img_size
        self.l=[]
        self.images=images
        self.transform = transform
        for i in os.listdir(self.images):
            if(i[1]!='_'):
                self.l.append((os.path.join(self.images,i),int(i[0]+i[1])))
            else:
                self.l.append((os.path.join(self.images,i),int(i[0])))



    def __len__(self):

        return len((self.l))

    def __getitem__(self, idx):
        img_path, label = self.l[idx]
        img = Image.open(img_path).convert('RGB')  # Ensure PIL image
        img = img.resize(self.img_size)  # Resize using PIL

        if self.transform:
            img = self.transform(img)  # Apply transformations (expects PIL or tensor)
        else:
            img = torch.tensor(np.array(img) / 255.0, dtype=torch.float32).permute(2, 0, 1)

        return img, label

# %%
train_set=food("/kaggle/input/food11/training",img_size) #,transform=transform)
val_set=food("/kaggle/input/food11/evaluation",img_size)
test_set=food("/kaggle/input/food11/validation",img_size)
train_dataloader = DataLoader(train_set, batch_size=8, shuffle=True, num_workers=4)
test_dataloader = DataLoader(test_set, batch_size=8, shuffle=False, num_workers=4)
val_dataloader=DataLoader(val_set,batch_size=8,shuffle=False,num_workers=4)
print(len(train_set))
print(len(test_set))
print(len(val_set))
# Out:
# 9866
# 3430
# 3347

# %%
import torch
from collections import Counter

# Initialize a Counter to store class frequencies
class_counts = Counter()

# Iterate over the dataloader
for _, labels in train_dataloader:  # Assuming labels are in the second position (input, label)
    labels = labels.cpu().numpy()
    class_counts.update(labels.tolist())


print("Class-wise sample counts:", dict(class_counts))
# Out:
# Class-wise sample counts: {10: 709, 8: 855, 6: 440, 4: 848, 2: 1500, 9: 1500, 3: 986, 0: 994, 5: 1325, 1: 429, 7: 280}

# %%
import torch
from collections import Counter


class_counts = Counter()

# Iterate over the dataloader
for _, labels in test_dataloader:
    labels = labels.numpy() if isinstance(labels, torch.Tensor) else labels
    class_counts.update(labels.tolist())


print("Class-wise sample counts in test set:", dict(class_counts))
# Out:
# Class-wise sample counts in test set: {8: 347, 5: 449, 9: 500, 0: 362, 3: 327, 2: 500, 4: 326, 10: 232, 6: 147, 1: 144, 7: 96}

# %%
import torch
from collections import Counter

# Initialize a dictionary to store class counts
class_counts = Counter()

# Iterate over the dataloader
for _, labels in val_dataloader:  # Assuming labels are in the second position (input, label)
    labels = labels.numpy() if isinstance(labels, torch.Tensor) else labels
    class_counts.update(labels.tolist())

# Print class-wise counts
print("Class-wise sample counts in validation:", dict(class_counts))
# Out:
# Class-wise sample counts in validation: {8: 303, 5: 432, 9: 500, 0: 368, 3: 335, 2: 500, 4: 287, 10: 231, 6: 147, 1: 148, 7: 96}

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the image
img = Image.open('/kaggle/input/food11/evaluation/10_112.jpg')

# Display the image using matplotlib
plt.imshow(img)
plt.axis('off')  # Optionally hide axis
plt.show()

# %% [markdown]
# ## Resnet18 Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![f9a8eaaa866c2b783162fe65afdff67171e993fb.png](data:image/png;base64,...)

# %%
class Resnet18(nn.Module):
    def __init__(self,out_classes):
        super(Resnet18,self).__init__()

        self.relu=nn.ReLU()
        self.dropoutp = 0.5
        #conv1
        self.conv11=nn.Conv2d(3,64,kernel_size=(7,7),stride=(2,2),padding=(3,3))
        self.batchnorm1=nn.BatchNorm2d(64)
        self.maxpool1=nn.MaxPool2d((3,3),stride=(2,2),padding=(1,1))


        # BLOCK-2(1) input=(56x56) output=(56x56)

        self.conv211=nn.Conv2d(64,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm211=nn.BatchNorm2d(64)
        self.conv212=nn.Conv2d(64,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm212=nn.BatchNorm2d(64)
        self.dropout21=nn.Dropout(p=self.dropoutp)
        # BLOCK-2(2)
        self.conv221=nn.Conv2d(64,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm221=nn.BatchNorm2d(64)
        self.conv222=nn.Conv2d(64,64,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm222=nn.BatchNorm2d(64)
        self.dropout22=nn.Dropout(p=self.dropoutp)

        # BLOCK-3(1) input=(56x56) output=(28x28)
        self.conv311=nn.Conv2d(64,128,kernel_size=(3,3),stride=(2,2),padding=(1,1))
        self.batchnorm311=nn.BatchNorm2d(128)
        self.conv312=nn.Conv2d(128,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm312=nn.BatchNorm2d(128)
        self.dropout31=nn.Dropout(p=self.dropoutp)
        self.concat_adjust31=nn.Conv2d(64,128,kernel_size=(1,1),stride=(2,2),padding=(0,0))
        #BLOCK-3(2)
        self.conv321=nn.Conv2d(128,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm321=nn.BatchNorm2d(128)
        self.conv322=nn.Conv2d(128,128,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm322=nn.BatchNorm2d(128)
        self.dropout32=nn.Dropout(p=self.dropoutp)

        #BLOCK-4(1)input=(28x28) ouput=(14x14)
        self.conv411=nn.Conv2d(128,256,kernel_size=(3,3),stride=(2,2),padding=(1,1))
        self.batchnorm411=nn.BatchNorm2d(256)
        self.conv412=nn.Conv2d(256,256,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm412=nn.BatchNorm2d(256)
        self.dropout41=nn.Dropout(p=self.dropoutp)
        self.concat_adjust41=nn.Conv2d(128,256,kernel_size=(1,1),stride=(2,2),padding=(0,0))

        #BLOCK-4(2)
        self.conv421=nn.Conv2d(256,256,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm421=nn.BatchNorm2d(256)
        self.conv422=nn.Conv2d(256,256,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm422=nn.BatchNorm2d(256)
        self.dropout42=nn.Dropout(p=self.dropoutp)

        #BLOCK-5(1) input=(14x14)  output=(7x7)
        self.conv511=nn.Conv2d(256,512,kernel_size=(3,3),stride=(2,2),padding=(1,1))
        self.batchnorm511=nn.BatchNorm2d(512)
        self.conv512=nn.Conv2d(512,512,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm512=nn.BatchNorm2d(512)
        self.dropout51=nn.Dropout(p=self.dropoutp)
        self.concat_adjust51=nn.Conv2d(256,512,kernel_size=(1,1),stride=(2,2),padding=(0,0))

        #BLOCK-5(2)
        self.conv521=nn.Conv2d(512,512,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm521=nn.BatchNorm2d(512)
        self.conv522=nn.Conv2d(512,512,kernel_size=(3,3),stride=(1,1),padding=(1,1))
        self.batchnorm522=nn.BatchNorm2d(512)
        self.dropout52=nn.Dropout(p=self.dropoutp)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc=nn.Linear(512,1000)
        self.out=nn.Linear(1000,out_classes)



    def forward(self,x):
        x=self.relu(self.batchnorm1(self.conv11(x)))
        x11=self.maxpool1(x)

        #block2-1
        x=self.conv211(x11)
        x=self.batchnorm211(x)
        x=self.relu(x)
        x=self.conv212(x)
        x=self.batchnorm212(x)
        x=self.dropout21(x)
        x21=self.relu(x+x11)

        #block2-2
        x=self.conv221(x21)
        x=self.batchnorm221(x)
        x=self.relu(x)
        x=self.conv222(x)
        x=self.batchnorm222(x)
        x=self.dropout22(x)
        x22=self.relu(x21+x)


        #block3-1
        x=self.conv311(x22)
        x=self.batchnorm311(x)
        x=self.relu(x)
        x=self.conv312(x)
        x=self.batchnorm312(x)
        x=self.dropout31(x)

        x22=self.concat_adjust31(x22)
        x31=self.relu(x+x22)

        #block3-2
        x=self.conv321(x31)
        x=self.batchnorm321(x)
        x=self.relu(x)
        x=self.conv322(x)
        x=self.batchnorm322(x)
        x=self.dropout32(x)

        x32=self.relu(x+x31)

        #block4-1
        x=self.conv411(x32)
        x=self.batchnorm411(x)
        x=self.relu(x)
        x=self.conv412(x)
        x=self.batchnorm412(x)
        x=self.dropout41(x)

        x32=self.concat_adjust41(x32)
        x41=self.relu((x+x32))

        #block4-2
        x=self.conv421(x41)
        x=self.batchnorm421(x)
        x=self.relu(x)
        x=self.conv422(x)
        x=self.batchnorm422(x)
        x=self.dropout42(x)

        x42=self.relu(x+x41)


        #block5-1
        x=self.conv511(x42)
        x=self.batchnorm511(x)
        x=self.relu(x)
        x=self.conv512(x)
        x=self.batchnorm512(x)
        x=self.dropout51(x)

        x42=self.concat_adjust51(x42)
        x51=self.relu(x+x42)

        #block5-2
        x=self.conv521(x51)
        x=self.batchnorm521(x)
        x=self.relu(x)
        x=self.conv522(x)
        x=self.batchnorm522(x)
        x=self.dropout52(x)

        x52=self.relu(x+x51)


        #linear block
        x=self.avgpool(x52)
        #print(x.shape)
        x= x.reshape(x.shape[0],-1)
        x=self.fc(x)
        x=self.relu(x)
        x=self.out(x)

        return x

# %%
model=Resnet18(11)
model.to(device)
# Out:
# Resnet18(
#   (relu): ReLU()
#   (conv11): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (batchnorm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=1, ceil_mode=False)
#   (conv211): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm211): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv212): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm212): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout21): Dropout(p=0.5, inplace=False)
#   (conv221): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm221): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv222): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm222): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout22): Dropout(p=0.5, inplace=False)
#   (conv311): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm311): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv312): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm312): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout31): Dropout(p=0.5, inplace=False)
#   (concat_adjust31): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#   (conv321): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm321): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv322): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm322): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout32): Dropout(p=0.5, inplace=False)
#   (conv411): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm411): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv412): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm412): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout41): Dropout(p=0.5, inplace=False)
#   (concat_adjust41): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#   (conv421): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm421): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv422): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm422): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout42): Dropout(p=0.5, inplace=False)
#   (conv511): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm511): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv512): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm512): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout51): Dropout(p=0.5, inplace=False)
#   (concat_adjust51): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#   (conv521): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm521): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv522): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm522): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout52): Dropout(p=0.5, inplace=False)
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
#   (out): Linear(in_features=1000, out_features=11, bias=True)
# )

# %%
from torchinfo import summary

# %%
summary(model=model, input_size=(8, 3, 224, 224), col_names=["input_size", "output_size", "num_params", "trainable"])
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# Resnet18                                 [8, 3, 224, 224]          [8, 11]                   --                        True
# ├─Conv2d: 1-1                            [8, 3, 224, 224]          [8, 64, 112, 112]         9,472                     True
# ├─BatchNorm2d: 1-2                       [8, 64, 112, 112]         [8, 64, 112, 112]         128                       True
# ├─ReLU: 1-3                              [8, 64, 112, 112]         [8, 64, 112, 112]         --                        --
# ├─MaxPool2d: 1-4                         [8, 64, 112, 112]         [8, 64, 56, 56]           --                        --
# ├─Conv2d: 1-5                            [8, 64, 56, 56]           [8, 64, 56, 56]           36,928                    True
# ├─BatchNorm2d: 1-6                       [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# ├─ReLU: 1-7                              [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Conv2d: 1-8                            [8, 64, 56, 56]           [8, 64, 56, 56]           36,928                    True
# ├─BatchNorm2d: 1-9                       [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# ├─Dropout: 1-10                          [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─ReLU: 1-11                             [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Conv2d: 1-12                           [8, 64, 56, 56]           [8, 64, 56, 56]           36,928                    True
# ├─BatchNorm2d: 1-13                      [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# ├─ReLU: 1-14                             [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Conv2d: 1-15                           [8, 64, 56, 56]           [8, 64, 56, 56]           36,928                    True
# ├─BatchNorm2d: 1-16                      [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# ├─Dropout: 1-17                          [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─ReLU: 1-18                             [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Conv2d: 1-19                           [8, 64, 56, 56]           [8, 128, 28, 28]          73,856                    True
# ├─BatchNorm2d: 1-20                      [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# ├─ReLU: 1-21                             [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Conv2d: 1-22                           [8, 128, 28, 28]          [8, 128, 28, 28]          147,584                   True
# ├─BatchNorm2d: 1-23                      [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# ├─Dropout: 1-24                          [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Conv2d: 1-25                           [8, 64, 56, 56]           [8, 128, 28, 28]          8,320                     True
# ├─ReLU: 1-26                             [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Conv2d: 1-27                           [8, 128, 28, 28]          [8, 128, 28, 28]          147,584                   True
# ├─BatchNorm2d: 1-28                      [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# ├─ReLU: 1-29                             [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Conv2d: 1-30                           [8, 128, 28, 28]          [8, 128, 28, 28]          147,584                   True
# ├─BatchNorm2d: 1-31                      [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# ├─Dropout: 1-32                          [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─ReLU: 1-33                             [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Conv2d: 1-34                           [8, 128, 28, 28]          [8, 256, 14, 14]          295,168                   True
# ├─BatchNorm2d: 1-35                      [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# ├─ReLU: 1-36                             [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Conv2d: 1-37                           [8, 256, 14, 14]          [8, 256, 14, 14]          590,080                   True
# ├─BatchNorm2d: 1-38                      [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# ├─Dropout: 1-39                          [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Conv2d: 1-40                           [8, 128, 28, 28]          [8, 256, 14, 14]          33,024                    True
# ├─ReLU: 1-41                             [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Conv2d: 1-42                           [8, 256, 14, 14]          [8, 256, 14, 14]          590,080                   True
# ├─BatchNorm2d: 1-43                      [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# ├─ReLU: 1-44                             [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Conv2d: 1-45                           [8, 256, 14, 14]          [8, 256, 14, 14]          590,080                   True
# ├─BatchNorm2d: 1-46                      [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# ├─Dropout: 1-47                          [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─ReLU: 1-48                             [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Conv2d: 1-49                           [8, 256, 14, 14]          [8, 512, 7, 7]            1,180,160                 True
# ├─BatchNorm2d: 1-50                      [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# ├─ReLU: 1-51                             [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─Conv2d: 1-52                           [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,808                 True
# ├─BatchNorm2d: 1-53                      [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# ├─Dropout: 1-54                          [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─Conv2d: 1-55                           [8, 256, 14, 14]          [8, 512, 7, 7]            131,584                   True
# ├─ReLU: 1-56                             [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─Conv2d: 1-57                           [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,808                 True
# ├─BatchNorm2d: 1-58                      [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# ├─ReLU: 1-59                             [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─Conv2d: 1-60                           [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,808                 True
# ├─BatchNorm2d: 1-61                      [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# ├─Dropout: 1-62                          [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─ReLU: 1-63                             [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─AdaptiveAvgPool2d: 1-64                [8, 512, 7, 7]            [8, 512, 1, 1]            --                        --
# ├─Linear: 1-65                           [8, 512]                  [8, 1000]                 513,000                   True
# ├─ReLU: 1-66                             [8, 1000]                 [8, 1000]                 --                        --
# ├─Linear: 1-67                           [8, 1000]                 [8, 11]                   11,011                    True
# ============================================================================================================================================
# Total params: 11,703,531
# Trainable params: 11,703,531
# Non-trainable params: 0
# Total mult-adds (G): 14.53
# ============================================================================================================================================
# Input size (MB): 4.82
# Forward/backward pass size (MB): 306.74
# Params size (MB): 46.81
# Estimated Total Size (MB): 358.37
# ============================================================================================================================================

# %%
pip install --upgrade calflops
# Out:
# Collecting calflops
#   Downloading calflops-0.3.2-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: accelerate>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (1.2.1)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from calflops) (0.27.0)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from calflops) (2.5.1+cu121)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.22.0->calflops) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (2024.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.16.4->calflops) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->calflops) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.1.0->calflops) (1.3.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->calflops) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.16.4->calflops) (2024.12.14)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<3.0.0,>=1.17->accelerate>=0.22.0->calflops) (2024.2.0)
# Downloading calflops-0.3.2-py3-none-any.whl (29 kB)
# Installing collected packages: calflops
# Successfully installed calflops-0.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from calflops import calculate_flops
from torchvision import models


batch_size = 1
input_shape = (batch_size, 3, 224, 224)
flops, macs, params = calculate_flops(model=model,
                                      input_shape=input_shape,
                                      output_as_string=True,
                                      output_precision=4)
print("FLOPs:%s   MACs:%s   Params:%s \n" %(flops, macs, params))
# Out:
# ------------------------------------- Calculate Flops Results -------------------------------------
# Notations:
# number of parameters (Params), number of multiply-accumulate operations(MACs),
# number of floating-point operations (FLOPs), floating-point operations per second (FLOPS),
# fwd FLOPs (model forward propagation FLOPs), bwd FLOPs (model backward propagation FLOPs),
# default model backpropagation takes 2.00 times as much computation as forward propagation.
#
# Total Training Params:                                                  11.7 M
# fwd MACs:                                                               1.8141 GMACs
# fwd FLOPs:                                                              3.6384 GFLOPS
# fwd+bwd MACs:                                                           5.4423 GMACs
# fwd+bwd FLOPs:                                                          10.9152 GFLOPS
#
# -------------------------------- Detailed Calculated FLOPs Results --------------------------------
# Each module caculated is listed after its name in the following order:
# params, percentage of total params, MACs, percentage of total MACs, FLOPS, percentage of total FLOPs
#
# Note: 1. A module can have torch.nn.module or torch.nn.functional to compute logits (e.g. CrossEntropyLoss).
#  They are not counted as submodules in calflops and not to be printed out. However they make up the difference between a parent's MACs and the sum of its submodules'.
# 2. Number of floating-point operations is a theoretical estimation, thus FLOPS computed using that could be larger than the maximum system throughput.
#
# Resnet18(
#   11.7 M = 100% Params, 1.81 GMACs = 100% MACs, 3.64 GFLOPS = 100% FLOPs
#   (relu): ReLU(0 = 0% Params, 0 MACs = 0% MACs, 2.31 MFLOPS = 0.0635% FLOPs)
#   (conv11): Conv2d(9.47 K = 0.0809% Params, 118.01 MMACs = 6.5054% MACs, 236.83 MFLOPS = 6.5092% FLOPs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (batchnorm1): BatchNorm2d(128 = 0.0011% Params, 0 MACs = 0% MACs, 1.61 MFLOPS = 0.0441% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(0 = 0% Params, 0 MACs = 0% MACs, 802.82 KFLOPS = 0.0221% FLOPs, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), dilation=1, ceil_mode=False)
#   (conv211): Conv2d(36.93 K = 0.3155% Params, 115.61 MMACs = 6.3727% MACs, 231.41 MFLOPS = 6.3603% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm211): BatchNorm2d(128 = 0.0011% Params, 0 MACs = 0% MACs, 401.41 KFLOPS = 0.011% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv212): Conv2d(36.93 K = 0.3155% Params, 115.61 MMACs = 6.3727% MACs, 231.41 MFLOPS = 6.3603% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm212): BatchNorm2d(128 = 0.0011% Params, 0 MACs = 0% MACs, 401.41 KFLOPS = 0.011% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout21): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (conv221): Conv2d(36.93 K = 0.3155% Params, 115.61 MMACs = 6.3727% MACs, 231.41 MFLOPS = 6.3603% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm221): BatchNorm2d(128 = 0.0011% Params, 0 MACs = 0% MACs, 401.41 KFLOPS = 0.011% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv222): Conv2d(36.93 K = 0.3155% Params, 115.61 MMACs = 6.3727% MACs, 231.41 MFLOPS = 6.3603% FLOPs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm222): BatchNorm2d(128 = 0.0011% Params, 0 MACs = 0% MACs, 401.41 KFLOPS = 0.011% FLOPs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout22): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (conv311): Conv2d(73.86 K = 0.6311% Params, 57.8 MMACs = 3.1863% MACs, 115.71 MFLOPS = 3.1801% FLOPs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm311): BatchNorm2d(256 = 0.0022% Params, 0 MACs = 0% MACs, 200.7 KFLOPS = 0.0055% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv312): Conv2d(147.58 K = 1.261% Params, 115.61 MMACs = 6.3727% MACs, 231.31 MFLOPS = 6.3575% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm312): BatchNorm2d(256 = 0.0022% Params, 0 MACs = 0% MACs, 200.7 KFLOPS = 0.0055% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout31): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (concat_adjust31): Conv2d(8.32 K = 0.0711% Params, 6.42 MMACs = 0.354% MACs, 12.95 MFLOPS = 0.3558% FLOPs, 64, 128, kernel_size=(1, 1), stride=(2, 2))
#   (conv321): Conv2d(147.58 K = 1.261% Params, 115.61 MMACs = 6.3727% MACs, 231.31 MFLOPS = 6.3575% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm321): BatchNorm2d(256 = 0.0022% Params, 0 MACs = 0% MACs, 200.7 KFLOPS = 0.0055% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv322): Conv2d(147.58 K = 1.261% Params, 115.61 MMACs = 6.3727% MACs, 231.31 MFLOPS = 6.3575% FLOPs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm322): BatchNorm2d(256 = 0.0022% Params, 0 MACs = 0% MACs, 200.7 KFLOPS = 0.0055% FLOPs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout32): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (conv411): Conv2d(295.17 K = 2.522% Params, 57.8 MMACs = 3.1863% MACs, 115.66 MFLOPS = 3.1787% FLOPs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm411): BatchNorm2d(512 = 0.0044% Params, 0 MACs = 0% MACs, 100.35 KFLOPS = 0.0028% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv412): Conv2d(590.08 K = 5.0419% Params, 115.61 MMACs = 6.3727% MACs, 231.26 MFLOPS = 6.3561% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm412): BatchNorm2d(512 = 0.0044% Params, 0 MACs = 0% MACs, 100.35 KFLOPS = 0.0028% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout41): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (concat_adjust41): Conv2d(33.02 K = 0.2822% Params, 6.42 MMACs = 0.354% MACs, 12.9 MFLOPS = 0.3544% FLOPs, 128, 256, kernel_size=(1, 1), stride=(2, 2))
#   (conv421): Conv2d(590.08 K = 5.0419% Params, 115.61 MMACs = 6.3727% MACs, 231.26 MFLOPS = 6.3561% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm421): BatchNorm2d(512 = 0.0044% Params, 0 MACs = 0% MACs, 100.35 KFLOPS = 0.0028% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv422): Conv2d(590.08 K = 5.0419% Params, 115.61 MMACs = 6.3727% MACs, 231.26 MFLOPS = 6.3561% FLOPs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm422): BatchNorm2d(512 = 0.0044% Params, 0 MACs = 0% MACs, 100.35 KFLOPS = 0.0028% FLOPs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout42): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (conv511): Conv2d(1.18 M = 10.0838% Params, 57.8 MMACs = 3.1863% MACs, 115.63 MFLOPS = 3.1781% FLOPs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (batchnorm511): BatchNorm2d(1.02 K = 0.0087% Params, 0 MACs = 0% MACs, 50.18 KFLOPS = 0.0014% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv512): Conv2d(2.36 M = 20.1632% Params, 115.61 MMACs = 6.3727% MACs, 231.24 MFLOPS = 6.3554% FLOPs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm512): BatchNorm2d(1.02 K = 0.0087% Params, 0 MACs = 0% MACs, 50.18 KFLOPS = 0.0014% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout51): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (concat_adjust51): Conv2d(131.58 K = 1.1243% Params, 6.42 MMACs = 0.354% MACs, 12.87 MFLOPS = 0.3537% FLOPs, 256, 512, kernel_size=(1, 1), stride=(2, 2))
#   (conv521): Conv2d(2.36 M = 20.1632% Params, 115.61 MMACs = 6.3727% MACs, 231.24 MFLOPS = 6.3554% FLOPs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm521): BatchNorm2d(1.02 K = 0.0087% Params, 0 MACs = 0% MACs, 50.18 KFLOPS = 0.0014% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv522): Conv2d(2.36 M = 20.1632% Params, 115.61 MMACs = 6.3727% MACs, 231.24 MFLOPS = 6.3554% FLOPs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchnorm522): BatchNorm2d(1.02 K = 0.0087% Params, 0 MACs = 0% MACs, 50.18 KFLOPS = 0.0014% FLOPs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout52): Dropout(0 = 0% Params, 0 MACs = 0% MACs, 0 FLOPS = 0% FLOPs, p=0.5, inplace=False)
#   (avgpool): AdaptiveAvgPool2d(0 = 0% Params, 0 MACs = 0% MACs, 25.09 KFLOPS = 0.0007% FLOPs, output_size=(1, 1))
#   (fc): Linear(513 K = 4.3833% Params, 512 KMACs = 0.0282% MACs, 1.02 MFLOPS = 0.0281% FLOPs, in_features=512, out_features=1000, bias=True)
#   (out): Linear(11.01 K = 0.0941% Params, 11 KMACs = 0.0006% MACs, 22 KFLOPS = 0.0006% FLOPs, in_features=1000, out_features=11, bias=True)
# )
# ---------------------------------------------------------------------------------------------------
# FLOPs:3.6384 GFLOPS   MACs:1.8141 GMACs   Params:11.7035 M

# %%
from torch.optim import Adam
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.0001)

# %%
import torch
from tqdm import tqdm

train_loss_score=[]
test_loss_score=[]
torch.manual_seed(40)
num_epochs = 24
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0

    # Training loop
    for X, Y in tqdm(train_dataloader, total=len(train_dataloader), leave=False):
        optimizer.zero_grad()
        X = X.to(device).float()
        Y = Y.to(device)

        # Forward pass
        outputs = model(X)


        targets = Y


        # Compute loss
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader.dataset)
    train_loss_score.append(epoch_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}')
    model.eval()
    test_loss = 0.0

    with torch.no_grad():
        for X_test, Y_test in tqdm(test_dataloader, total=len(test_dataloader), leave=False):
            X_test = X_test.to(device).float()
            Y_test = Y_test.to(device)

            # Forward pass
            outputs_test = model(X_test)


            targets_test = Y_test

            # Compute loss
            test_loss += criterion(outputs_test, targets_test).item()

    test_loss /= len(test_dataloader.dataset)
    test_loss_score.append(test_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss:.4f}')


print("Training  complete!")
# Out:
# Epoch [1/24], Training Loss: 0.2556
# Epoch [1/24], Test Loss: 0.2319
# Epoch [2/24], Training Loss: 0.2334
# Epoch [2/24], Test Loss: 0.2416
# Epoch [3/24], Training Loss: 0.2173
# Epoch [3/24], Test Loss: 0.2054
# Epoch [4/24], Training Loss: 0.2026
# Epoch [4/24], Test Loss: 0.2059
# Epoch [5/24], Training Loss: 0.1914
# Epoch [5/24], Test Loss: 0.1967
# Epoch [6/24], Training Loss: 0.1813
# Epoch [6/24], Test Loss: 0.1814
# Epoch [7/24], Training Loss: 0.1677
# Epoch [7/24], Test Loss: 0.1728
# Epoch [8/24], Training Loss: 0.1581
# Epoch [8/24], Test Loss: 0.1779
# Epoch [9/24], Training Loss: 0.1508
# Epoch [9/24], Test Loss: 0.1678
# Epoch [10/24], Training Loss: 0.1419
# Epoch [10/24], Test Loss: 0.1572
# Epoch [11/24], Training Loss: 0.1343
# Epoch [11/24], Test Loss: 0.1421
# Epoch [12/24], Training Loss: 0.1267
# Epoch [12/24], Test Loss: 0.1410
# Epoch [13/24], Training Loss: 0.1206
# Epoch [13/24], Test Loss: 0.1694
# Epoch [14/24], Training Loss: 0.1132
# Epoch [14/24], Test Loss: 0.1606
# Epoch [15/24], Training Loss: 0.1062
# Epoch [15/24], Test Loss: 0.1662
# Epoch [16/24], Training Loss: 0.1016
# Epoch [16/24], Test Loss: 0.1312
# Epoch [17/24], Training Loss: 0.0959
# Epoch [17/24], Test Loss: 0.1399
# Epoch [18/24], Training Loss: 0.0873
# Epoch [18/24], Test Loss: 0.1443
# Epoch [19/24], Training Loss: 0.0820
# Epoch [19/24], Test Loss: 0.1682
# Epoch [20/24], Training Loss: 0.0764
# Epoch [20/24], Test Loss: 0.1399
# Epoch [21/24], Training Loss: 0.0712
# Epoch [21/24], Test Loss: 0.1427
# Epoch [22/24], Training Loss: 0.0668
# Epoch [22/24], Test Loss: 0.1444
# Epoch [23/24], Training Loss: 0.0604
# Epoch [23/24], Test Loss: 0.1419
# Epoch [24/24], Training Loss: 0.0568
# Epoch [24/24], Test Loss: 0.1561
# Training  complete!

# %% [markdown]
# ## Training and Test loss visualisation

# %%
plt.plot(train_loss_score,color='red')
plt.xlabel("Epochs")
plt.ylabel("Train loss")
plt.show()

# %%
plt.plot(test_loss_score,color='red')
plt.xlabel("Epochs")
plt.ylabel("Test loss")
plt.show()

# %%
pip install torcheval
# Out:
# Collecting torcheval
#   Downloading torcheval-0.0.7-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torcheval) (4.12.2)
# Downloading torcheval-0.0.7-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 4.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torcheval
# Successfully installed torcheval-0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from torcheval.metrics import MulticlassAccuracy
metric = MulticlassAccuracy(num_classes=11)

# %%
model.eval()
with torch.no_grad():
    for x_batch, y_batch in val_dataloader:

        x_batch, y_batch = x_batch.to(device), y_batch.to(device)


        outputs = model(x_batch)


        predictions = torch.argmax(outputs, dim=1)
        metric.update(predictions, y_batch)

# Compute final accuracy
accuracy = metric.compute()
print(f"Overall Accuracy: {accuracy.item():.4f}")
# Out:
# Overall Accuracy: 0.6722

# %%
import torch
import torch.nn as nn
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import numpy as np

class_names = [
    "Bread", "Dairy product", "Dessert", "Egg", "Fried food",
    "Meat", "Noodles/Pasta", "Rice", "Seafood", "Soup", "Vegetable/Fruit"
]


num_classes = len(class_names)


softmax = nn.Softmax(dim=1)


all_true_labels = []
all_pred_labels = []

model.eval()


with torch.no_grad():  # No need to compute gradients during inference
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)

        predicted = softmax(outputs).argmax(dim=1)

        # Store true labels and predicted labels for metrics calculation
        all_true_labels.extend(labels.cpu().numpy())
        all_pred_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays for evaluation
all_true_labels = np.array(all_true_labels)
all_pred_labels = np.array(all_pred_labels)


cm = confusion_matrix(all_true_labels, all_pred_labels, labels=np.arange(num_classes))
print("Confusion Matrix:")
print(cm)

# Compute precision, recall, and F1-score per class
precision = precision_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)
recall = recall_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)
f1 = f1_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)


print("\nClass-wise Metrics:")
for i in range(num_classes):
    print(f"{class_names[i]:<15} - Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1-score: {f1[i]:.4f}")

# Compute and print overall (weighted) metrics
precision_avg = precision_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)
recall_avg = recall_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)
f1_avg = f1_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)

print("\nOverall Metrics:")
print(f"Average Precision: {precision_avg:.4f}")
print(f"Average Recall: {recall_avg:.4f}")
print(f"Average F1 Score: {f1_avg:.4f}")
# Out:
# Confusion Matrix:
# [[204  18  13  64  21  16   5   1   6  18   2]
#  [  6  94   4  14   8   6   0   4   1   7   4]
#  [ 29  92 162  34  18  88   1   5  12  50   9]
#  [ 27  14   4 261   3   9   7   2   1   6   1]
#  [ 17  14   7  15 203  18   0   1   3   9   0]
#  [ 24   5   5  21  22 340   1   1   3   9   1]
#  [  8   0   0  13   0   1 105   9   0  10   1]
#  [ 12   0   1   1   3   1  12  58   0   3   5]
#  [ 16  33  13  16   7  24   0   1 163  15  15]
#  [  3   9   6   6   5   2   6   0   1 460   2]
#  [  2   4   3   8   6   4   1   0   3   0 200]]
#
# Class-wise Metrics:
# Bread           - Precision: 0.5862, Recall: 0.5543, F1-score: 0.5698
# Dairy product   - Precision: 0.3322, Recall: 0.6351, F1-score: 0.4362
# Dessert         - Precision: 0.7431, Recall: 0.3240, F1-score: 0.4513
# Egg             - Precision: 0.5762, Recall: 0.7791, F1-score: 0.6624
# Fried food      - Precision: 0.6858, Recall: 0.7073, F1-score: 0.6964
# Meat            - Precision: 0.6680, Recall: 0.7870, F1-score: 0.7226
# Noodles/Pasta   - Precision: 0.7609, Recall: 0.7143, F1-score: 0.7368
# Rice            - Precision: 0.7073, Recall: 0.6042, F1-score: 0.6517
# Seafood         - Precision: 0.8446, Recall: 0.5380, F1-score: 0.6573
# Soup            - Precision: 0.7836, Recall: 0.9200, F1-score: 0.8464
# Vegetable/Fruit - Precision: 0.8333, Recall: 0.8658, F1-score: 0.8493
#
# Overall Metrics:
# Average Precision: 0.6976
# Average Recall: 0.6722
# Average F1 Score: 0.6642

# %% [markdown]
# # Transfer learning on same dataset

# %%
import torchvision

# %%
weights=torchvision.models.ResNet18_Weights.DEFAULT
model1=torchvision.models.resnet18(weights=weights)
model1.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
summary(model=model1, input_size=(8, 3, 224, 224), col_names=["input_size", "output_size", "num_params", "trainable"])
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# ResNet                                   [8, 3, 224, 224]          [8, 1000]                 --                        True
# ├─Conv2d: 1-1                            [8, 3, 224, 224]          [8, 64, 112, 112]         9,408                     True
# ├─BatchNorm2d: 1-2                       [8, 64, 112, 112]         [8, 64, 112, 112]         128                       True
# ├─ReLU: 1-3                              [8, 64, 112, 112]         [8, 64, 112, 112]         --                        --
# ├─MaxPool2d: 1-4                         [8, 64, 112, 112]         [8, 64, 56, 56]           --                        --
# ├─Sequential: 1-5                        [8, 64, 56, 56]           [8, 64, 56, 56]           --                        True
# │    └─BasicBlock: 2-1                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        True
# │    │    └─Conv2d: 3-1                  [8, 64, 56, 56]           [8, 64, 56, 56]           36,864                    True
# │    │    └─BatchNorm2d: 3-2             [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# │    │    └─ReLU: 3-3                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    │    └─Conv2d: 3-4                  [8, 64, 56, 56]           [8, 64, 56, 56]           36,864                    True
# │    │    └─BatchNorm2d: 3-5             [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# │    │    └─ReLU: 3-6                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    └─BasicBlock: 2-2                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        True
# │    │    └─Conv2d: 3-7                  [8, 64, 56, 56]           [8, 64, 56, 56]           36,864                    True
# │    │    └─BatchNorm2d: 3-8             [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# │    │    └─ReLU: 3-9                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    │    └─Conv2d: 3-10                 [8, 64, 56, 56]           [8, 64, 56, 56]           36,864                    True
# │    │    └─BatchNorm2d: 3-11            [8, 64, 56, 56]           [8, 64, 56, 56]           128                       True
# │    │    └─ReLU: 3-12                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Sequential: 1-6                        [8, 64, 56, 56]           [8, 128, 28, 28]          --                        True
# │    └─BasicBlock: 2-3                   [8, 64, 56, 56]           [8, 128, 28, 28]          --                        True
# │    │    └─Conv2d: 3-13                 [8, 64, 56, 56]           [8, 128, 28, 28]          73,728                    True
# │    │    └─BatchNorm2d: 3-14            [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# │    │    └─ReLU: 3-15                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    │    └─Conv2d: 3-16                 [8, 128, 28, 28]          [8, 128, 28, 28]          147,456                   True
# │    │    └─BatchNorm2d: 3-17            [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# │    │    └─Sequential: 3-18             [8, 64, 56, 56]           [8, 128, 28, 28]          8,448                     True
# │    │    └─ReLU: 3-19                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    └─BasicBlock: 2-4                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        True
# │    │    └─Conv2d: 3-20                 [8, 128, 28, 28]          [8, 128, 28, 28]          147,456                   True
# │    │    └─BatchNorm2d: 3-21            [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# │    │    └─ReLU: 3-22                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    │    └─Conv2d: 3-23                 [8, 128, 28, 28]          [8, 128, 28, 28]          147,456                   True
# │    │    └─BatchNorm2d: 3-24            [8, 128, 28, 28]          [8, 128, 28, 28]          256                       True
# │    │    └─ReLU: 3-25                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Sequential: 1-7                        [8, 128, 28, 28]          [8, 256, 14, 14]          --                        True
# │    └─BasicBlock: 2-5                   [8, 128, 28, 28]          [8, 256, 14, 14]          --                        True
# │    │    └─Conv2d: 3-26                 [8, 128, 28, 28]          [8, 256, 14, 14]          294,912                   True
# │    │    └─BatchNorm2d: 3-27            [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# │    │    └─ReLU: 3-28                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    │    └─Conv2d: 3-29                 [8, 256, 14, 14]          [8, 256, 14, 14]          589,824                   True
# │    │    └─BatchNorm2d: 3-30            [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# │    │    └─Sequential: 3-31             [8, 128, 28, 28]          [8, 256, 14, 14]          33,280                    True
# │    │    └─ReLU: 3-32                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    └─BasicBlock: 2-6                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        True
# │    │    └─Conv2d: 3-33                 [8, 256, 14, 14]          [8, 256, 14, 14]          589,824                   True
# │    │    └─BatchNorm2d: 3-34            [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# │    │    └─ReLU: 3-35                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    │    └─Conv2d: 3-36                 [8, 256, 14, 14]          [8, 256, 14, 14]          589,824                   True
# │    │    └─BatchNorm2d: 3-37            [8, 256, 14, 14]          [8, 256, 14, 14]          512                       True
# │    │    └─ReLU: 3-38                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Sequential: 1-8                        [8, 256, 14, 14]          [8, 512, 7, 7]            --                        True
# │    └─BasicBlock: 2-7                   [8, 256, 14, 14]          [8, 512, 7, 7]            --                        True
# │    │    └─Conv2d: 3-39                 [8, 256, 14, 14]          [8, 512, 7, 7]            1,179,648                 True
# │    │    └─BatchNorm2d: 3-40            [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# │    │    └─ReLU: 3-41                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    │    └─Conv2d: 3-42                 [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,296                 True
# │    │    └─BatchNorm2d: 3-43            [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# │    │    └─Sequential: 3-44             [8, 256, 14, 14]          [8, 512, 7, 7]            132,096                   True
# │    │    └─ReLU: 3-45                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    └─BasicBlock: 2-8                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        True
# │    │    └─Conv2d: 3-46                 [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,296                 True
# │    │    └─BatchNorm2d: 3-47            [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# │    │    └─ReLU: 3-48                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    │    └─Conv2d: 3-49                 [8, 512, 7, 7]            [8, 512, 7, 7]            2,359,296                 True
# │    │    └─BatchNorm2d: 3-50            [8, 512, 7, 7]            [8, 512, 7, 7]            1,024                     True
# │    │    └─ReLU: 3-51                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─AdaptiveAvgPool2d: 1-9                 [8, 512, 7, 7]            [8, 512, 1, 1]            --                        --
# ├─Linear: 1-10                           [8, 512]                  [8, 1000]                 513,000                   True
# ============================================================================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (G): 14.51
# ============================================================================================================================================
# Input size (MB): 4.82
# Forward/backward pass size (MB): 317.98
# Params size (MB): 46.76
# Estimated Total Size (MB): 369.55
# ============================================================================================================================================

# %%
model1.fc
# Out:
# Linear(in_features=512, out_features=1000, bias=True)

# %%
for param in model1.parameters():
    param.requires_grad = False  # Freeze feature extractor (Conv layers)


in_features = model.fc.in_features


model1.fc = nn.Sequential(
    nn.Linear(in_features, 11)
)

# %%
model1.fc
# Out:
# Sequential(
#   (0): Linear(in_features=512, out_features=11, bias=True)
# )

# %%
summary(model=model1, input_size=(8, 3, 224, 224), col_names=["input_size", "output_size", "num_params", "trainable"])
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# ResNet                                   [8, 3, 224, 224]          [8, 11]                   --                        Partial
# ├─Conv2d: 1-1                            [8, 3, 224, 224]          [8, 64, 112, 112]         (9,408)                   False
# ├─BatchNorm2d: 1-2                       [8, 64, 112, 112]         [8, 64, 112, 112]         (128)                     False
# ├─ReLU: 1-3                              [8, 64, 112, 112]         [8, 64, 112, 112]         --                        --
# ├─MaxPool2d: 1-4                         [8, 64, 112, 112]         [8, 64, 56, 56]           --                        --
# ├─Sequential: 1-5                        [8, 64, 56, 56]           [8, 64, 56, 56]           --                        False
# │    └─BasicBlock: 2-1                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        False
# │    │    └─Conv2d: 3-1                  [8, 64, 56, 56]           [8, 64, 56, 56]           (36,864)                  False
# │    │    └─BatchNorm2d: 3-2             [8, 64, 56, 56]           [8, 64, 56, 56]           (128)                     False
# │    │    └─ReLU: 3-3                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    │    └─Conv2d: 3-4                  [8, 64, 56, 56]           [8, 64, 56, 56]           (36,864)                  False
# │    │    └─BatchNorm2d: 3-5             [8, 64, 56, 56]           [8, 64, 56, 56]           (128)                     False
# │    │    └─ReLU: 3-6                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    └─BasicBlock: 2-2                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        False
# │    │    └─Conv2d: 3-7                  [8, 64, 56, 56]           [8, 64, 56, 56]           (36,864)                  False
# │    │    └─BatchNorm2d: 3-8             [8, 64, 56, 56]           [8, 64, 56, 56]           (128)                     False
# │    │    └─ReLU: 3-9                    [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# │    │    └─Conv2d: 3-10                 [8, 64, 56, 56]           [8, 64, 56, 56]           (36,864)                  False
# │    │    └─BatchNorm2d: 3-11            [8, 64, 56, 56]           [8, 64, 56, 56]           (128)                     False
# │    │    └─ReLU: 3-12                   [8, 64, 56, 56]           [8, 64, 56, 56]           --                        --
# ├─Sequential: 1-6                        [8, 64, 56, 56]           [8, 128, 28, 28]          --                        False
# │    └─BasicBlock: 2-3                   [8, 64, 56, 56]           [8, 128, 28, 28]          --                        False
# │    │    └─Conv2d: 3-13                 [8, 64, 56, 56]           [8, 128, 28, 28]          (73,728)                  False
# │    │    └─BatchNorm2d: 3-14            [8, 128, 28, 28]          [8, 128, 28, 28]          (256)                     False
# │    │    └─ReLU: 3-15                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    │    └─Conv2d: 3-16                 [8, 128, 28, 28]          [8, 128, 28, 28]          (147,456)                 False
# │    │    └─BatchNorm2d: 3-17            [8, 128, 28, 28]          [8, 128, 28, 28]          (256)                     False
# │    │    └─Sequential: 3-18             [8, 64, 56, 56]           [8, 128, 28, 28]          (8,448)                   False
# │    │    └─ReLU: 3-19                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    └─BasicBlock: 2-4                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        False
# │    │    └─Conv2d: 3-20                 [8, 128, 28, 28]          [8, 128, 28, 28]          (147,456)                 False
# │    │    └─BatchNorm2d: 3-21            [8, 128, 28, 28]          [8, 128, 28, 28]          (256)                     False
# │    │    └─ReLU: 3-22                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# │    │    └─Conv2d: 3-23                 [8, 128, 28, 28]          [8, 128, 28, 28]          (147,456)                 False
# │    │    └─BatchNorm2d: 3-24            [8, 128, 28, 28]          [8, 128, 28, 28]          (256)                     False
# │    │    └─ReLU: 3-25                   [8, 128, 28, 28]          [8, 128, 28, 28]          --                        --
# ├─Sequential: 1-7                        [8, 128, 28, 28]          [8, 256, 14, 14]          --                        False
# │    └─BasicBlock: 2-5                   [8, 128, 28, 28]          [8, 256, 14, 14]          --                        False
# │    │    └─Conv2d: 3-26                 [8, 128, 28, 28]          [8, 256, 14, 14]          (294,912)                 False
# │    │    └─BatchNorm2d: 3-27            [8, 256, 14, 14]          [8, 256, 14, 14]          (512)                     False
# │    │    └─ReLU: 3-28                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    │    └─Conv2d: 3-29                 [8, 256, 14, 14]          [8, 256, 14, 14]          (589,824)                 False
# │    │    └─BatchNorm2d: 3-30            [8, 256, 14, 14]          [8, 256, 14, 14]          (512)                     False
# │    │    └─Sequential: 3-31             [8, 128, 28, 28]          [8, 256, 14, 14]          (33,280)                  False
# │    │    └─ReLU: 3-32                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    └─BasicBlock: 2-6                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        False
# │    │    └─Conv2d: 3-33                 [8, 256, 14, 14]          [8, 256, 14, 14]          (589,824)                 False
# │    │    └─BatchNorm2d: 3-34            [8, 256, 14, 14]          [8, 256, 14, 14]          (512)                     False
# │    │    └─ReLU: 3-35                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# │    │    └─Conv2d: 3-36                 [8, 256, 14, 14]          [8, 256, 14, 14]          (589,824)                 False
# │    │    └─BatchNorm2d: 3-37            [8, 256, 14, 14]          [8, 256, 14, 14]          (512)                     False
# │    │    └─ReLU: 3-38                   [8, 256, 14, 14]          [8, 256, 14, 14]          --                        --
# ├─Sequential: 1-8                        [8, 256, 14, 14]          [8, 512, 7, 7]            --                        False
# │    └─BasicBlock: 2-7                   [8, 256, 14, 14]          [8, 512, 7, 7]            --                        False
# │    │    └─Conv2d: 3-39                 [8, 256, 14, 14]          [8, 512, 7, 7]            (1,179,648)               False
# │    │    └─BatchNorm2d: 3-40            [8, 512, 7, 7]            [8, 512, 7, 7]            (1,024)                   False
# │    │    └─ReLU: 3-41                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    │    └─Conv2d: 3-42                 [8, 512, 7, 7]            [8, 512, 7, 7]            (2,359,296)               False
# │    │    └─BatchNorm2d: 3-43            [8, 512, 7, 7]            [8, 512, 7, 7]            (1,024)                   False
# │    │    └─Sequential: 3-44             [8, 256, 14, 14]          [8, 512, 7, 7]            (132,096)                 False
# │    │    └─ReLU: 3-45                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    └─BasicBlock: 2-8                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        False
# │    │    └─Conv2d: 3-46                 [8, 512, 7, 7]            [8, 512, 7, 7]            (2,359,296)               False
# │    │    └─BatchNorm2d: 3-47            [8, 512, 7, 7]            [8, 512, 7, 7]            (1,024)                   False
# │    │    └─ReLU: 3-48                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# │    │    └─Conv2d: 3-49                 [8, 512, 7, 7]            [8, 512, 7, 7]            (2,359,296)               False
# │    │    └─BatchNorm2d: 3-50            [8, 512, 7, 7]            [8, 512, 7, 7]            (1,024)                   False
# │    │    └─ReLU: 3-51                   [8, 512, 7, 7]            [8, 512, 7, 7]            --                        --
# ├─AdaptiveAvgPool2d: 1-9                 [8, 512, 7, 7]            [8, 512, 1, 1]            --                        --
# ├─Sequential: 1-10                       [8, 512]                  [8, 11]                   --                        True
# │    └─Linear: 2-9                       [8, 512]                  [8, 11]                   5,643                     True
# ============================================================================================================================================
# Total params: 11,182,155
# Trainable params: 5,643
# Non-trainable params: 11,176,512
# Total mult-adds (G): 14.51
# ============================================================================================================================================
# Input size (MB): 4.82
# Forward/backward pass size (MB): 317.92
# Params size (MB): 44.73
# Estimated Total Size (MB): 367.46
# ============================================================================================================================================

# %%
from torch.optim import Adam
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model1.parameters(), lr=0.0001)

# %%
import torch
from tqdm import tqdm

train_loss_score=[]
test_loss_score=[]
torch.manual_seed(40)
num_epochs = 15
for epoch in range(num_epochs):
    model1.train()
    running_loss = 0.0

    # Training loop
    for X, Y in tqdm(train_dataloader, total=len(train_dataloader), leave=False):
        optimizer.zero_grad()
        X = X.to(device).float()
        Y = Y.to(device)

        # Forward pass
        outputs = model1(X)


        targets = Y


        # Compute loss
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    epoch_loss = running_loss / len(train_dataloader.dataset)
    train_loss_score.append(epoch_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}')
    model1.eval()
    test_loss = 0.0

    with torch.no_grad():
        for X_test, Y_test in tqdm(test_dataloader, total=len(test_dataloader), leave=False):
            X_test = X_test.to(device).float()
            Y_test = Y_test.to(device)

            # Forward pass
            outputs_test = model1(X_test)


            targets_test = Y_test

            # Compute loss
            test_loss += criterion(outputs_test, targets_test).item()

    test_loss /= len(test_dataloader.dataset)
    test_loss_score.append(test_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Test Loss: {test_loss:.4f}')


print("Training  complete!")
# Out:
# Epoch [1/15], Training Loss: 0.2290
# Epoch [1/15], Test Loss: 0.1731
# Epoch [2/15], Training Loss: 0.1685
# Epoch [2/15], Test Loss: 0.1325
# Epoch [3/15], Training Loss: 0.1434
# Epoch [3/15], Test Loss: 0.1154
# Epoch [4/15], Training Loss: 0.1293
# Epoch [4/15], Test Loss: 0.1113
# Epoch [5/15], Training Loss: 0.1223
# Epoch [5/15], Test Loss: 0.1034
# Epoch [6/15], Training Loss: 0.1177
# Epoch [6/15], Test Loss: 0.0963
# Epoch [7/15], Training Loss: 0.1125
# Epoch [7/15], Test Loss: 0.0971
# Epoch [8/15], Training Loss: 0.1094
# Epoch [8/15], Test Loss: 0.0960
# Epoch [9/15], Training Loss: 0.1069
# Epoch [9/15], Test Loss: 0.0930
# Epoch [10/15], Training Loss: 0.1046
# Epoch [10/15], Test Loss: 0.0900
# Epoch [11/15], Training Loss: 0.1021
# Epoch [11/15], Test Loss: 0.0885
# Epoch [12/15], Training Loss: 0.1005
# Epoch [12/15], Test Loss: 0.0889
# Epoch [13/15], Training Loss: 0.1010
# Epoch [13/15], Test Loss: 0.0881
# Epoch [14/15], Training Loss: 0.0981
# Epoch [14/15], Test Loss: 0.0868
# Epoch [15/15], Training Loss: 0.0978
# Epoch [15/15], Test Loss: 0.0876
# Training  complete!

# %%
plt.plot(train_loss_score,color='red')
plt.xlabel("Epochs")
plt.ylabel("Train loss")
plt.show()

# %%
plt.plot(test_loss_score,color='red')
plt.xlabel("Epochs")
plt.ylabel("Test loss")
plt.show()

# %%
model.eval()
with torch.no_grad():
    for x_batch, y_batch in val_dataloader:

        x_batch, y_batch = x_batch.to(device), y_batch.to(device)


        outputs = model(x_batch)


        predictions = torch.argmax(outputs, dim=1)
        metric.update(predictions, y_batch)

# Compute final accuracy
accuracy = metric.compute()
print(f"Overall Accuracy: {accuracy.item():.4f}")
# Out:
# Overall Accuracy: 0.6722

# %%
import torch
import torch.nn as nn
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import numpy as np

class_names = [
    "Bread", "Dairy product", "Dessert", "Egg", "Fried food",
    "Meat", "Noodles/Pasta", "Rice", "Seafood", "Soup", "Vegetable/Fruit"
]


num_classes = len(class_names)


softmax = nn.Softmax(dim=1)


all_true_labels = []
all_pred_labels = []

model.eval()


with torch.no_grad():  # No need to compute gradients during inference
    for inputs, labels in val_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)

        predicted = softmax(outputs).argmax(dim=1)

        # Store true labels and predicted labels for metrics calculation
        all_true_labels.extend(labels.cpu().numpy())
        all_pred_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays for evaluation
all_true_labels = np.array(all_true_labels)
all_pred_labels = np.array(all_pred_labels)


cm = confusion_matrix(all_true_labels, all_pred_labels, labels=np.arange(num_classes))
print("Confusion Matrix:")
print(cm)

# Compute precision, recall, and F1-score per class
precision = precision_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)
recall = recall_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)
f1 = f1_score(all_true_labels, all_pred_labels, average=None, labels=np.arange(num_classes), zero_division=0)


print("\nClass-wise Metrics:")
for i in range(num_classes):
    print(f"{class_names[i]:<15} - Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1-score: {f1[i]:.4f}")

# Compute and print overall (weighted) metrics
precision_avg = precision_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)
recall_avg = recall_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)
f1_avg = f1_score(all_true_labels, all_pred_labels, average='weighted', labels=np.arange(num_classes), zero_division=0)

print("\nOverall Metrics:")
print(f"Average Precision: {precision_avg:.4f}")
print(f"Average Recall: {recall_avg:.4f}")
print(f"Average F1 Score: {f1_avg:.4f}")
# Out:
# Confusion Matrix:
# [[204  18  13  64  21  16   5   1   6  18   2]
#  [  6  94   4  14   8   6   0   4   1   7   4]
#  [ 29  92 162  34  18  88   1   5  12  50   9]
#  [ 27  14   4 261   3   9   7   2   1   6   1]
#  [ 17  14   7  15 203  18   0   1   3   9   0]
#  [ 24   5   5  21  22 340   1   1   3   9   1]
#  [  8   0   0  13   0   1 105   9   0  10   1]
#  [ 12   0   1   1   3   1  12  58   0   3   5]
#  [ 16  33  13  16   7  24   0   1 163  15  15]
#  [  3   9   6   6   5   2   6   0   1 460   2]
#  [  2   4   3   8   6   4   1   0   3   0 200]]
#
# Class-wise Metrics:
# Bread           - Precision: 0.5862, Recall: 0.5543, F1-score: 0.5698
# Dairy product   - Precision: 0.3322, Recall: 0.6351, F1-score: 0.4362
# Dessert         - Precision: 0.7431, Recall: 0.3240, F1-score: 0.4513
# Egg             - Precision: 0.5762, Recall: 0.7791, F1-score: 0.6624
# Fried food      - Precision: 0.6858, Recall: 0.7073, F1-score: 0.6964
# Meat            - Precision: 0.6680, Recall: 0.7870, F1-score: 0.7226
# Noodles/Pasta   - Precision: 0.7609, Recall: 0.7143, F1-score: 0.7368
# Rice            - Precision: 0.7073, Recall: 0.6042, F1-score: 0.6517
# Seafood         - Precision: 0.8446, Recall: 0.5380, F1-score: 0.6573
# Soup            - Precision: 0.7836, Recall: 0.9200, F1-score: 0.8464
# Vegetable/Fruit - Precision: 0.8333, Recall: 0.8658, F1-score: 0.8493
#
# Overall Metrics:
# Average Precision: 0.6976
# Average Recall: 0.6722
# Average F1 Score: 0.6642
